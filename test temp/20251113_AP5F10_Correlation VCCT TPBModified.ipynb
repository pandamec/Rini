# %%
using DataFrames, XLSX, CSV
using CairoMakie

# %%
df= XLSX.readtable("250918_TPBModified2.xlsx", "Sheet1") |> DataFrame
# Out:
# 66×50 DataFrame
#  Row │ N    Separation  PrecrackRechts  CrackFront  CrackClosed  dy    S_Alle  ⋯
#      │ Any  Any         Any             Any         Any          Any   Any     ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 1    10          10              2           1            0.25  57.7401 ⋯
#    2 │ 2    10          10              2           1            0.5   116.057
#    3 │ 3    10          10              2           1            0.75  174.758
#    4 │ 4    10          10              2           1            1     233.768
#    5 │ 5    10          10              2           1            1.25  292.95  ⋯
#    6 │ 6    10          10              2           1            1.5   354.322
#    7 │ 7    10          20              2           1            0.25  57.7392
#    8 │ 8    10          20              2           1            0.5   116.055
#   ⋮  │  ⋮       ⋮             ⋮             ⋮            ⋮        ⋮       ⋮    ⋱
#   60 │ 60   10          300             2           1            1.5   733.768 ⋯
#   61 │ 61   10          500             2           1            0.25  113.5
#   62 │ 62   10          500             2           1            0.5   236.925
#   63 │ 63   10          500             2           1            0.75  367.407
#   64 │ 64   10          500             2           1            1     502.773 ⋯
#   65 │ 65   10          500             2           1            1.25  637.913
#   66 │ 66   10          500             2           1            1.5   771.843
#                                                   43 columns and 51 rows omitted

# %% [markdown]
# ## Figure Stress Curves

# %%
# Plot the first curve with lines and markers
fig = Figure(resolution = (1200, 1200))
font=24
ax1_1 = Axis(fig[1,1],
    xlabel = L"w (mm)",
    ylabel = L"P (N)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)


ax2_1 = Axis(fig[1,2],
    xlabel = L"w (mm)",
    ylabel = L"τ (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)

ax3_1 = Axis(fig[1,3],
    xlabel = L"w (um)",
    ylabel = L"σ (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)

ax4_1 = Axis(fig[2,1],
    xlabel = L"a (um)",
    ylabel = L"τ(MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)

ax5_1 = Axis(fig[2,2],
    xlabel = L"a (um)",
    ylabel = L"σ (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)
# Out:
# Axis with 0 plots:

# %% [markdown]
# ## Figure VCCT Curves

# %%
# Plot the first curve with lines and markers
fig2 = Figure(resolution = (1200, 1200))
font=24


ax1_2 = Axis(fig2[1,1],
    xlabel = L"w (mm)",
    ylabel = L"ux1-ux2  (um)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)


ax2_2 = Axis(fig2[1,2],
    xlabel = L"w (mm)",
    ylabel = L"uy1-uy2 (um)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)


ax3_2 = Axis(fig2[1,3],
    xlabel = L"ux1-ux2  (um)",
    ylabel = L"Fx (N)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)

ax4_2 = Axis(fig2[2,1],
    xlabel = L"uy1-uy2  (um)",
    ylabel = L"Fy (N)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)



ax5_2 = Axis(fig2[2,2],
    xlabel = L"δy (um)",
    ylabel = L"Fy (N)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)

ax6_2 = Axis(fig2[3,1],
    xlabel = L"w (mm)",
    ylabel = L"GI(J/m2)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)

ax7_2 = Axis(fig2[3,2],
    xlabel = L"w (mm)",
    ylabel = L"GII(J/m2)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)
# Out:
# Axis with 0 plots:

# %% [markdown]
# ## Functions

# %%
function filter_range2(df::DataFrame, column::String, low, high)
    return filter(row -> low ≤ row[column] ≤ high, df)
end
# Out:
# filter_range2 (generic function with 1 method)

# %%
function filter_range(df::DataFrame, column::String, a0)
    return filter(row -> row[column] ==a0, df)
end
# Out:
# filter_range (generic function with 1 method)

# %%
function plotBendingCurves(ax1,ax2,ax3,ax4,ax5,df)
    Makie.scatter!(ax1,abs.(df[!,:dy]),abs.(df[!,:P]))
    Makie.lines!(ax1,abs.(df[!,:dy]),abs.(df[!,:P]))

    Makie.scatter!(ax2,abs.(df[!,:dy]),abs.(df[!,:τ_front]))
    Makie.lines!(ax2,abs.(df[!,:dy]),abs.(df[!,:τ_front]))

    Makie.scatter!(ax3,abs.(df[!,:dy]),abs.(df[!,:σ_front]))
    Makie.lines!(ax3,abs.(df[!,:dy]),abs.(df[!,:σ_front]))


    Makie.scatter!(ax4,abs.(df[!,:PrecrackRechts]),abs.(df[!,:τ_front]))
    Makie.lines!(ax4,abs.(df[!,:PrecrackRechts]),abs.(df[!,:τ_front]))


    Makie.scatter!(ax5,abs.(df[!,:PrecrackRechts]),abs.(df[!,:σ_front]))
    Makie.lines!(ax5,abs.(df[!,:PrecrackRechts]),abs.(df[!,:σ_front]))


end
# Out:
# plotBendingCurves (generic function with 1 method)

# %%
function plotProperties2!(fig, df_log,ax1,ax2,ax3)
        

        epsilon=df_log[!," Strain Rate[%/min]"]
        E=df_log[!,"E[GPa] "]
        Makie.scatter!(ax1,epsilon,E)
        Makie.lines!(ax1,epsilon,E)

        Makie.scatter!(ax2,df_log[!," Strain Rate[%/min]"],df_log[!,"sigmaMax"])
        Makie.lines!(ax2,df_log[!," Strain Rate[%/min]"],df_log[!,"sigmaMax"])


        Makie.scatter!(ax3,df_log[!," Strain Rate[%/min]"],df_log[!,"sigma0_25% "])
        Makie.lines!(ax3,df_log[!," Strain Rate[%/min]"],df_log[!,"sigma0_25% "])
        
        
        return fig

end
# Out:
# plotProperties2! (generic function with 1 method)

# %%
function plotVCCTCurves(ax1,ax2,ax3,ax4,ax5,ax6,ax7,df)
    Makie.scatter!(ax1,abs.(df[!,:dy]),abs.(df[!,:δ_x]))
    Makie.lines!(ax1,abs.(df[!,:dy]),abs.(df[!,:δ_x]))

    Makie.scatter!(ax2,abs.(df[!,:dy]),abs.(df[!,:δ_y]))
    Makie.lines!(ax2,abs.(df[!,:dy]),abs.(df[!,:δ_y]))

    Makie.scatter!(ax3,abs.(df[!,:δ_x]),abs.(df[!,:Fx_Front]))
    Makie.lines!(ax3,abs.(df[!,:δ_x]),abs.(df[!,:Fx_Front]))


    Makie.scatter!(ax4,abs.(df[!,:δ_y]),abs.(df[!,:Fy_Front]))
    Makie.lines!(ax4,abs.(df[!,:δ_y]),abs.(df[!,:Fy_Front]))

    Makie.scatter!(ax5,abs.(df[!,:delta_y]),abs.(df[!,:Fy_Front]))
    Makie.lines!(ax5,abs.(df[!,:delta_y]),abs.(df[!,:Fy_Front]))

    Makie.scatter!(ax6,abs.(df[!,:dy]),abs.(df[!,:GI]))
    Makie.lines!(ax6,abs.(df[!,:dy]),abs.(df[!,:GI]))

    Makie.scatter!(ax7,abs.(df[!,:dy]),abs.(df[!,:GII]))
    Makie.lines!(ax7,abs.(df[!,:dy]),abs.(df[!,:GII]))
end
# Out:
# plotVCCTCurves (generic function with 1 method)

# %%
df
# Out:
# 66×50 DataFrame
#  Row │ N    Separation  PrecrackRechts  CrackFront  CrackClosed  dy    S_Alle  ⋯
#      │ Any  Any         Any             Any         Any          Any   Any     ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 1    10          10              2           1            0.25  57.7401 ⋯
#    2 │ 2    10          10              2           1            0.5   116.057
#    3 │ 3    10          10              2           1            0.75  174.758
#    4 │ 4    10          10              2           1            1     233.768
#    5 │ 5    10          10              2           1            1.25  292.95  ⋯
#    6 │ 6    10          10              2           1            1.5   354.322
#    7 │ 7    10          20              2           1            0.25  57.7392
#    8 │ 8    10          20              2           1            0.5   116.055
#   ⋮  │  ⋮       ⋮             ⋮             ⋮            ⋮        ⋮       ⋮    ⋱
#   60 │ 60   10          300             2           1            1.5   733.768 ⋯
#   61 │ 61   10          500             2           1            0.25  113.5
#   62 │ 62   10          500             2           1            0.5   236.925
#   63 │ 63   10          500             2           1            0.75  367.407
#   64 │ 64   10          500             2           1            1     502.773 ⋯
#   65 │ 65   10          500             2           1            1.25  637.913
#   66 │ 66   10          500             2           1            1.5   771.843
#                                                   43 columns and 51 rows omitted

# %%
width=2*1e-3 #m
delta_crack=2e-6 #m 
s_crack=width*delta_crack #m2
# Out:
# 4.0e-9

# %%
df[!,:GI]=(df[!,:Fy_Front].*(df[!,:dy_Parylene]-df[!,:dy_Si])*-1*1e-3)/(2*s_crack)
df[!,:GII]=(df[!,:Fx_Front].*(df[!,:dx_Parylene]-df[!,:dx_Si])*-1*1e-3)/(2*s_crack)
df[!,:δ_x]=(-df[!,:dx_Parylene]+df[!,:dx_Si])
df[!,:δ_y]=(-df[!,:dy_Parylene]+df[!,:dy_Si])
df[!,:τ_front]=df[!,:Fx_Front]*1e-6./s_crack #MPa
df[!,:σ_front]=df[!,:Fy_Front]*1e-6./s_crack #MPa
df[!,:delta_y]=(-df[!,:deltay_Parylene]+df[!,:deltay_Si]) ## Aperture in um
# Out:
# 66-element Vector{Float64}:
#  3.702734829860027e-5
#  6.933987606309866e-5
#  9.836367098599308e-5
#  0.00012325472198398968
#  0.00014860415831299822
#  0.00017556885723099547
#  6.636400939889764e-5
#  0.0001253720256500085
#  0.00018007995095099816
#  0.00022944004740602097
#  ⋮
#  0.0013452372513720057
#  0.0016654958017169874
#  0.0019819854060190156
#  0.0005283436621540058
#  0.0010354342521168014
#  0.0015312689356510034
#  0.002017637598328015
#  0.002503817086108001
#  0.0029835937311880056

# %%
df
# Out:
# 66×57 DataFrame
#  Row │ N    Separation  PrecrackRechts  CrackFront  CrackClosed  dy    S_Alle  ⋯
#      │ Any  Any         Any             Any         Any          Any   Any     ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 1    10          10              2           1            0.25  57.7401 ⋯
#    2 │ 2    10          10              2           1            0.5   116.057
#    3 │ 3    10          10              2           1            0.75  174.758
#    4 │ 4    10          10              2           1            1     233.768
#    5 │ 5    10          10              2           1            1.25  292.95  ⋯
#    6 │ 6    10          10              2           1            1.5   354.322
#    7 │ 7    10          20              2           1            0.25  57.7392
#    8 │ 8    10          20              2           1            0.5   116.055
#   ⋮  │  ⋮       ⋮             ⋮             ⋮            ⋮        ⋮       ⋮    ⋱
#   60 │ 60   10          300             2           1            1.5   733.768 ⋯
#   61 │ 61   10          500             2           1            0.25  113.5
#   62 │ 62   10          500             2           1            0.5   236.925
#   63 │ 63   10          500             2           1            0.75  367.407
#   64 │ 64   10          500             2           1            1     502.773 ⋯
#   65 │ 65   10          500             2           1            1.25  637.913
#   66 │ 66   10          500             2           1            1.5   771.843
#                                                   50 columns and 51 rows omitted

# %%
df_dy1=Float64.(filter_range(df,"dy",1))
# Out:
# 11×57 DataFrame
#  Row │ N        Separation  PrecrackRechts  CrackFront  CrackClosed  dy        ⋯
#      │ Float64  Float64     Float64         Float64     Float64      Float64   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │     4.0        10.0            10.0         2.0          1.0      1.0   ⋯
#    2 │    10.0        10.0            20.0         2.0          1.0      1.0
#    3 │    16.0        10.0            30.0         2.0          1.0      1.0
#    4 │    22.0        10.0            40.0         2.0          1.0      1.0
#    5 │    28.0        10.0            50.0         2.0          1.0      1.0   ⋯
#    6 │    34.0        10.0            75.0         2.0          1.0      1.0
#    7 │    40.0        10.0           100.0         2.0          1.0      1.0
#    8 │    46.0        10.0           150.0         2.0          1.0      1.0
#    9 │    52.0        10.0           200.0         2.0          1.0      1.0   ⋯
#   10 │    58.0        10.0           300.0         2.0          1.0      1.0
#   11 │    64.0        10.0           500.0         2.0          1.0      1.0
#                                                               51 columns omitted

# %%
using Pkg
Pkg.add("Interpolations")
# Out:
#     Updating registry at `C:\Users\rinc\.julia\registries\General.toml`
#    Resolving package versions...
#     Updating `D:\01 Projekt\03 Programm\Rini aktuell\Rini\Project.toml`
#   [a98d9a8b] + Interpolations v0.16.2
#   No Changes to `D:\01 Projekt\03 Programm\Rini aktuell\Rini\Manifest.toml`

# %%
using Interpolations

# %%
a=df_dy1."PrecrackRechts"
G=-df_dy1."GII"
# Out:
# 11-element Vector{Float64}:
#   0.09435897954008204
#   0.7170681138498558
#   1.8909882018577244
#   3.3375157645336673
#   4.723318547994989
#   7.1096466020264355
#   8.22444227896993
#   9.047112307624277
#   9.517418418336966
#  10.180832738706638
#  11.357554473431275

# %%
itp = interpolate((a,), G, Gridded(Linear()))
val = itp(100)
# Out:
# 8.22444227896993

# %% [markdown]
# ## Pre crack 10 um

# %%
df_10=Float64.(filter_range(df,"PrecrackRechts",10))
# Out:
# 0×56 DataFrame
#  Row │ N    Separation  PreCrack  CrackFront  CrackClosed  dy   S_Alle  S_Stah ⋯
#      │ Any  Any         Any       Any         Any          Any  Any     Any    ⋯
# ─────┴──────────────────────────────────────────────────────────────────────────
#                                                               49 columns omitted

# %%
Makie.scatter!(ax1,df_10[!,:dy],df_10[!,:P])
Makie.lines!(ax1,df_10[!,:dy],df_10[!,:P])

Makie.scatter!(ax2,df_10[!,:dy],-df_10[!,:δ_x])
Makie.lines!(ax2,df_10[!,:dy],-df_10[!,:δ_x])

Makie.scatter!(ax3,df_10[!,:dy],-df_10[!,:δ_y])
Makie.lines!(ax3,df_10[!,:dy],-df_10[!,:δ_y])

Makie.scatter!(ax4,df_10[!,:dy],-df_10[!,:σx_front])
Makie.lines!(ax4,df_10[!,:dy],-df_10[!,:σx_front])


Makie.scatter!(ax5,df_10[!,:dy],-df_10[!,:σy_front])
Makie.lines!(ax5,df_10[!,:dy],-df_10[!,:σy_front])

Makie.scatter!(ax6,df_10[!,:dy],df_10[!,:G2])
Makie.lines!(ax6,df_10[!,:dy],df_10[!,:G2])



fig
# Out:
# UndefVarError: `ax1` not defined
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ d:\01 Projekt\03 Programm\Rini aktuell\Rini\test temp\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X52sZmlsZQ==.jl:1

# %% [markdown]
# ## Pre crack 10 50 100 200 300 500

# %%
for i in [50, 100, 300,500]

    df_filter=Float64.(filter_range(df,"PrecrackRechts",i))
    plotBendingCurves(ax1_1,ax2_1,ax3_1,ax4_1,ax5_1,df_filter)
    plotVCCTCurves(ax1_2,ax2_2,ax3_2,ax4_2,ax5_2,ax6_2,ax7_2,df_filter)
end

# %%
fig

# %%
fig2

# %% [markdown]
# ## Experimental Fatigue AP5F10

# %%
function importTest(path)

    #file = XLSX.readxlsx(path)
    df=CSV.read(path,DataFrame) 
    
    for col in names(df)
        if eltype(df[!, col]) <: AbstractString
           
                df[!, col] = parse.(Float64, replace.(df[!, col], "," => "."))
                # skip columns that cannot be converted
            
           
        end
    end

    return df
end
# Out:
# importTest (generic function with 1 method)

# %%
file_path = "D:/01 Projekt/03 Programm/Rini aktuell/Rini/development/fatigue delamination/AP5F10_Fatigue.csv"

df_exp=importTest(file_path)
df_study=importTest(file_path)
# Out:
# 9×6 DataFrame
#  Row │ Name        Sample    d        l0          lf          N
#      │ String15?   String1?  Int64?   Float64?    Float64?    Int64?
# ─────┼────────────────────────────────────────────────────────────────
#    1 │ 250908-2_A  A              10     1861.26     1853.68    10000
#    2 │ 250908-2_B  B              10     1697.49     1692.73    10000
#    3 │ 250911-2_A  A              10     1882.92     1879.51    10000
#    4 │ 250911-2_B  B              10     1833.4      1804.86    10000
#    5 │ 250908-1_A  A              10     1858.17     1829.01    20000
#    6 │ 250908-1_B  B              10     1869.4      1835.36    20000
#    7 │ 250911-1_A  A              10     1786.19     1758.86    30000
#    8 │ 250911-1_B  B              10     1875.07     1848.43    30000
#    9 │ missing     missing   missing  missing     missing     missing

# %%
df_exp
# Out:
# 9×6 DataFrame
#  Row │ Name        Sample    d        l0          lf          N
#      │ String15?   String1?  Int64?   Float64?    Float64?    Int64?
# ─────┼────────────────────────────────────────────────────────────────
#    1 │ 250908-2_A  A              10     1861.26     1853.68    10000
#    2 │ 250908-2_B  B              10     1697.49     1692.73    10000
#    3 │ 250911-2_A  A              10     1882.92     1879.51    10000
#    4 │ 250911-2_B  B              10     1833.4      1804.86    10000
#    5 │ 250908-1_A  A              10     1858.17     1829.01    20000
#    6 │ 250908-1_B  B              10     1869.4      1835.36    20000
#    7 │ 250911-1_A  A              10     1786.19     1758.86    30000
#    8 │ 250911-1_B  B              10     1875.07     1848.43    30000
#    9 │ missing     missing   missing  missing     missing     missing

# %%
delete!(df_exp, 2)
# Out:
# 8×6 DataFrame
#  Row │ Name        Sample    d        l0          lf          N
#      │ String15?   String1?  Int64?   Float64?    Float64?    Int64?
# ─────┼────────────────────────────────────────────────────────────────
#    1 │ 250908-2_A  A              10     1861.26     1853.68    10000
#    2 │ 250911-2_A  A              10     1882.92     1879.51    10000
#    3 │ 250911-2_B  B              10     1833.4      1804.86    10000
#    4 │ 250908-1_A  A              10     1858.17     1829.01    20000
#    5 │ 250908-1_B  B              10     1869.4      1835.36    20000
#    6 │ 250911-1_A  A              10     1786.19     1758.86    30000
#    7 │ 250911-1_B  B              10     1875.07     1848.43    30000
#    8 │ missing     missing   missing  missing     missing     missing

# %%
delete!(df_exp, 8)
# Out:
# 7×6 DataFrame
#  Row │ Name        Sample    d       l0        lf        N
#      │ String15?   String1?  Int64?  Float64?  Float64?  Int64?
# ─────┼──────────────────────────────────────────────────────────
#    1 │ 250908-2_A  A             10   1861.26   1853.68   10000
#    2 │ 250911-2_A  A             10   1882.92   1879.51   10000
#    3 │ 250911-2_B  B             10   1833.4    1804.86   10000
#    4 │ 250908-1_A  A             10   1858.17   1829.01   20000
#    5 │ 250908-1_B  B             10   1869.4    1835.36   20000
#    6 │ 250911-1_A  A             10   1786.19   1758.86   30000
#    7 │ 250911-1_B  B             10   1875.07   1848.43   30000

# %%
delete!(df_exp, 3)
# Out:
# 6×6 DataFrame
#  Row │ Name        Sample    d       l0        lf        N
#      │ String15?   String1?  Int64?  Float64?  Float64?  Int64?
# ─────┼──────────────────────────────────────────────────────────
#    1 │ 250908-2_A  A             10   1861.26   1853.68   10000
#    2 │ 250911-2_A  A             10   1882.92   1879.51   10000
#    3 │ 250908-1_A  A             10   1858.17   1829.01   20000
#    4 │ 250908-1_B  B             10   1869.4    1835.36   20000
#    5 │ 250911-1_A  A             10   1786.19   1758.86   30000
#    6 │ 250911-1_B  B             10   1875.07   1848.43   30000

# %%
delete!(df_exp, 5)
# Out:
# 5×6 DataFrame
#  Row │ Name        Sample    d       l0        lf        N
#      │ String15?   String1?  Int64?  Float64?  Float64?  Int64?
# ─────┼──────────────────────────────────────────────────────────
#    1 │ 250908-2_A  A             10   1861.26   1853.68   10000
#    2 │ 250911-2_A  A             10   1882.92   1879.51   10000
#    3 │ 250908-1_A  A             10   1858.17   1829.01   20000
#    4 │ 250908-1_B  B             10   1869.4    1835.36   20000
#    5 │ 250911-1_B  B             10   1875.07   1848.43   30000

# %%
df_exp[!,:a]=2000 .- df_exp[!,:lf]
df_exp[!,:a0]=2000 .- df_exp[!,:l0]
# Out:
# 5-element Vector{Float64}:
#  138.73900000000003
#  117.08400000000006
#  141.82500000000005
#  130.596
#  124.92599999999993

# %%
df_exp
# Out:
# 5×8 DataFrame
#  Row │ Name        Sample    d       l0        lf        N       a        a0   ⋯
#      │ String15?   String1?  Int64?  Float64?  Float64?  Int64?  Float64  Floa ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 250908-2_A  A             10   1861.26   1853.68   10000  146.321  138. ⋯
#    2 │ 250911-2_A  A             10   1882.92   1879.51   10000  120.491  117.
#    3 │ 250908-1_A  A             10   1858.17   1829.01   20000  170.994  141.
#    4 │ 250908-1_B  B             10   1869.4    1835.36   20000  164.637  130.
#    5 │ 250911-1_B  B             10   1875.07   1848.43   30000  151.572  124. ⋯
#                                                                 1 column omitted

# %%
df_exp[!,:delta_a]= df_exp[!,:a] -df_exp[!,:a0]
# Out:
# 5-element Vector{Float64}:
#   7.58199999999988
#   3.4069999999999254
#  29.16899999999987
#  34.04099999999994
#  26.645999999999958

# %%
df_exp[!,:dadN]= df_exp[!,:delta_a]./df_exp[!,:N]
# Out:
# 5-element Vector{Float64}:
#  0.000758199999999988
#  0.00034069999999999256
#  0.0014584499999999935
#  0.001702049999999997
#  0.0008881999999999986

# %%
df_exp
# Out:
# 5×10 DataFrame
#  Row │ Name        Sample    d       l0        lf        N       a        a0   ⋯
#      │ String15?   String1?  Int64?  Float64?  Float64?  Int64?  Float64  Floa ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 250908-2_A  A             10   1861.26   1853.68   10000  146.321  138. ⋯
#    2 │ 250911-2_A  A             10   1882.92   1879.51   10000  120.491  117.
#    3 │ 250908-1_A  A             10   1858.17   1829.01   20000  170.994  141.
#    4 │ 250908-1_B  B             10   1869.4    1835.36   20000  164.637  130.
#    5 │ 250911-1_B  B             10   1875.07   1848.43   30000  151.572  124. ⋯
#                                                                3 columns omitted

# %%
df_N10 = df[coalesce.(df."N" .== 10000, false), :]
df_N20 = df[coalesce.(df."N" .== 20000, false), :]
df_N30 = df[coalesce.(df."N" .== 30000, false), :]
# Out:
# 0×57 DataFrame
#  Row │ N    Separation  PrecrackRechts  CrackFront  CrackClosed  dy   S_Alle   ⋯
#      │ Any  Any         Any             Any         Any          Any  Any      ⋯
# ─────┴──────────────────────────────────────────────────────────────────────────
#                                                               50 columns omitted

# %%
df_A = df[coalesce.(df."Sample" .== "A", false), :]
df_B = df[coalesce.(df."Sample" .== "B", false), :]
# Out:
# ArgumentError: column name :Sample not found in the data frame
#
#
#
# Stacktrace:
#
#  [1] lookupname
#
#    @ C:\Users\rinc\.julia\packages\DataFrames\rwKZk\src\other\index.jl:431 [inlined]
#
#  [2] getindex
#
#    @ C:\Users\rinc\.julia\packages\DataFrames\rwKZk\src\other\index.jl:440 [inlined]
#
#  [3] getindex
#
#    @ C:\Users\rinc\.julia\packages\DataFrames\rwKZk\src\other\index.jl:441 [inlined]
#
#  [4] getindex(df::DataFrame, ::typeof(!), col_ind::String)
#
#    @ DataFrames C:\Users\rinc\.julia\packages\DataFrames\rwKZk\src\dataframe\dataframe.jl:557
#
#  [5] getproperty(df::DataFrame, col_ind::String)
#
#    @ DataFrames C:\Users\rinc\.julia\packages\DataFrames\rwKZk\src\abstractdataframe\abstractdataframe.jl:449
#
#  [6] top-level scope
#
#    @ d:\01 Projekt\03 Programm\Rini aktuell\Rini\test temp\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_Y120sZmlsZQ==.jl:1

# %%
df_A
# Out:
# 4×10 DataFrame
#  Row │ Name        Sample    d       l0        lf        N       a        a0   ⋯
#      │ String15?   String1?  Int64?  Float64?  Float64?  Int64?  Float64  Floa ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 250908-2_A  A             10   1861.26   1853.68   10000  146.321  138. ⋯
#    2 │ 250911-2_A  A             10   1882.92   1879.51   10000  120.491  117.
#    3 │ 250908-1_A  A             10   1858.17   1829.01   20000  170.994  141.
#    4 │ 250911-1_A  A             10   1786.19   1758.86   30000  241.138  213.
#                                                                3 columns omitted

# %%
GII_exp=[]
# Out:
# Any[]

# %%
df_exp
# Out:
# 5×10 DataFrame
#  Row │ Name        Sample    d       l0        lf        N       a        a0   ⋯
#      │ String15?   String1?  Int64?  Float64?  Float64?  Int64?  Float64  Floa ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 250908-2_A  A             10   1861.26   1853.68   10000  146.321  138. ⋯
#    2 │ 250911-2_A  A             10   1882.92   1879.51   10000  120.491  117.
#    3 │ 250908-1_A  A             10   1858.17   1829.01   20000  170.994  141.
#    4 │ 250908-1_B  B             10   1869.4    1835.36   20000  164.637  130.
#    5 │ 250911-1_B  B             10   1875.07   1848.43   30000  151.572  124. ⋯
#                                                                3 columns omitted

# %%
for i in df_exp."a"
    push!(GII_exp,itp(i))

end

# %%
for i in df."a"
    push!(GII_exp,itp(i))

end
# Out:
# ArgumentError: column name "a" not found in the data frame; existing most similar names are: "N", "P", "GI" and "dy"
#
#
#
# Stacktrace:
#
#  [1] lookupname
#
#    @ C:\Users\rinc\.julia\packages\DataFrames\rwKZk\src\other\index.jl:434 [inlined]
#
#  [2] getindex
#
#    @ C:\Users\rinc\.julia\packages\DataFrames\rwKZk\src\other\index.jl:440 [inlined]
#
#  [3] getindex
#
#    @ C:\Users\rinc\.julia\packages\DataFrames\rwKZk\src\other\index.jl:441 [inlined]
#
#  [4] getindex(df::DataFrame, ::typeof(!), col_ind::String)
#
#    @ DataFrames C:\Users\rinc\.julia\packages\DataFrames\rwKZk\src\dataframe\dataframe.jl:557
#
#  [5] getproperty(df::DataFrame, col_ind::String)
#
#    @ DataFrames C:\Users\rinc\.julia\packages\DataFrames\rwKZk\src\abstractdataframe\abstractdataframe.jl:449
#
#  [6] top-level scope
#
#    @ d:\01 Projekt\03 Programm\Rini aktuell\Rini\test temp\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_Y141sZmlsZQ==.jl:1

# %%
GII_exp=Float64.(GII_exp)
# Out:
# 5-element Vector{Float64}:
#  8.986580246915889
#  8.561588910113054
#  9.24458443739032
#  9.18478971847431
#  9.061898731745082

# %%
dadN=df_exp."dadN"
# Out:
# 5-element Vector{Float64}:
#  0.000758199999999988
#  0.00034069999999999256
#  0.0014584499999999935
#  0.001702049999999997
#  0.0008881999999999986

# %%
font = 36
fig = Figure(resolution = (1000, 600))

ax = Axis(fig[1, 1],
    xlabel = L"\Delta G~(\mathrm{J/m^2})",
    ylabel = L"\frac{da}{dN}~(\mu\mathrm{m/cycle})",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridvisible = false,   # kein vertikales Grid
    ygridvisible = false 

)
#ax.xticks = 0:5000:30000

CairoMakie.scatter!(ax, GII_exp, dadN;
                    marker = :utriangle,
                    markersize = 28,
                    color = :black)

fig
