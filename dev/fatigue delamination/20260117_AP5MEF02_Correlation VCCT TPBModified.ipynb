# %%
using DataFrames, XLSX, CSV
using CairoMakie

# %%
df= XLSX.readtable("AP5MEF02_Sim2.xlsx", "Sheet1") |> DataFrame
# Out:
# 30×36 DataFrame
#  Row │ N    Precrack  PrecrackRechts  SiAbstandRechts  SiRechts  dy   S_AlleMa ⋯
#      │ Any  Any       Any             Any              Any       Any  Any      ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 1    0.1       0.1             21.25            21.25     0.5  65.4525  ⋯
#    2 │ 2    0.1       0.1             21.25            21.25     1    131.033
#    3 │ 3    0.1       0.1             21.25            21.25     1.5  196.709
#    4 │ 4    0.1       0.1             21.25            21.25     2    262.551
#    5 │ 5    0.1       0.1             21.25            21.25     2.5  328.478  ⋯
#    6 │ 6    0.1       0.1             21.25            21.25     3    394.524
#    7 │ 7    0.3       0.3             21.25            21.25     0.5  65.3797
#    8 │ 8    0.3       0.3             21.25            21.25     1    130.892
#   ⋮  │  ⋮      ⋮            ⋮                ⋮            ⋮       ⋮       ⋮    ⋱
#   24 │ 24   0.75      0.75            21.25            21.25     3    392.428  ⋯
#   25 │ 25   1         1               21.25            21.25     0.5  64.7919
#   26 │ 26   1         1               21.25            21.25     1    129.752
#   27 │ 27   1         1               21.25            21.25     1.5  194.81
#   28 │ 28   1         1               21.25            21.25     2    259.971  ⋯
#   29 │ 29   1         1               21.25            21.25     2.5  325.25
#   30 │ 30   1         1               21.25            21.25     3    390.641
#                                                   30 columns and 15 rows omitted

# %% [markdown]
# ## Figure Stress Curves

# %%
# Plot the first curve with lines and markers
fig = Figure(resolution = (1200, 1200))
font=24
ax1_1 = Axis(fig[1,1],
    xlabel = L"w (mm)",
    ylabel = L"P (N)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)


ax2_1 = Axis(fig[1,2],
    xlabel = L"w (mm)",
    ylabel = L"τ (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)

ax3_1 = Axis(fig[1,3],
    xlabel = L"w (um)",
    ylabel = L"σ (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)

ax4_1 = Axis(fig[2,1],
    xlabel = L"a (um)",
    ylabel = L"τ(MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)

ax5_1 = Axis(fig[2,2],
    xlabel = L"a (um)",
    ylabel = L"σ (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)
# Out:
# Axis with 0 plots:

# %% [markdown]
# ## Figure VCCT Curves

# %%
# Plot the first curve with lines and markers
fig2 = Figure(resolution = (1200, 1200))
font=24


ax1_2 = Axis(fig2[1,1],
    xlabel = L"w (mm)",
    ylabel = L"ux1-ux2  (um)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)


ax2_2 = Axis(fig2[1,2],
    xlabel = L"w (mm)",
    ylabel = L"uy1-uy2 (um)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)


ax3_2 = Axis(fig2[1,3],
    xlabel = L"ux1-ux2  (um)",
    ylabel = L"Fx (N)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)

ax4_2 = Axis(fig2[2,1],
    xlabel = L"uy1-uy2  (um)",
    ylabel = L"Fy (N)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)



ax5_2 = Axis(fig2[2,2],
    xlabel = L"δy (um)",
    ylabel = L"Fy (N)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)

ax6_2 = Axis(fig2[3,1],
    xlabel = L"w (mm)",
    ylabel = L"GI(J/m2)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)

ax7_2 = Axis(fig2[3,2],
    xlabel = L"w (mm)",
    ylabel = L"GII(J/m2)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)
# Out:
# Axis with 0 plots:

# %% [markdown]
# ## Functions

# %%
function filter_range2(df::DataFrame, column::String, low, high)
    return filter(row -> low ≤ row[column] ≤ high, df)
end
# Out:
# filter_range2 (generic function with 1 method)

# %%
function filter_range(df::DataFrame, column::String, a0)
    return filter(row -> row[column] ==a0, df)
end
# Out:
# filter_range (generic function with 1 method)

# %%
function plotBendingCurves(ax1,ax2,ax3,ax4,ax5,df)
    Makie.scatter!(ax1,abs.(df[!,:dy]),abs.(df[!,:P]))
    Makie.lines!(ax1,abs.(df[!,:dy]),abs.(df[!,:P]))

    Makie.scatter!(ax2,abs.(df[!,:dy]),abs.(df[!,:τ_front]))
    Makie.lines!(ax2,abs.(df[!,:dy]),abs.(df[!,:τ_front]))

    Makie.scatter!(ax3,abs.(df[!,:dy]),abs.(df[!,:σ_front]))
    Makie.lines!(ax3,abs.(df[!,:dy]),abs.(df[!,:σ_front]))


    Makie.scatter!(ax4,abs.(df[!,:PrecrackRechts]),abs.(df[!,:τ_front]))
    Makie.lines!(ax4,abs.(df[!,:PrecrackRechts]),abs.(df[!,:τ_front]))


    Makie.scatter!(ax5,abs.(df[!,:PrecrackRechts]),abs.(df[!,:σ_front]))
    Makie.lines!(ax5,abs.(df[!,:PrecrackRechts]),abs.(df[!,:σ_front]))


end
# Out:
# plotBendingCurves (generic function with 1 method)

# %%
function plotProperties2!(fig, df_log,ax1,ax2,ax3)
        

        epsilon=df_log[!," Strain Rate[%/min]"]
        E=df_log[!,"E[GPa] "]
        Makie.scatter!(ax1,epsilon,E)
        Makie.lines!(ax1,epsilon,E)

        Makie.scatter!(ax2,df_log[!," Strain Rate[%/min]"],df_log[!,"sigmaMax"])
        Makie.lines!(ax2,df_log[!," Strain Rate[%/min]"],df_log[!,"sigmaMax"])


        Makie.scatter!(ax3,df_log[!," Strain Rate[%/min]"],df_log[!,"sigma0_25% "])
        Makie.lines!(ax3,df_log[!," Strain Rate[%/min]"],df_log[!,"sigma0_25% "])
        
        
        return fig

end
# Out:
# plotProperties2! (generic function with 1 method)

# %%
function plotVCCTCurves(ax1,ax2,ax3,ax4,ax5,ax6,ax7,df)
    Makie.scatter!(ax1,abs.(df[!,:dy]),abs.(df[!,:δ_x]))
    Makie.lines!(ax1,abs.(df[!,:dy]),abs.(df[!,:δ_x]))

    Makie.scatter!(ax2,abs.(df[!,:dy]),abs.(df[!,:δ_y]))
    Makie.lines!(ax2,abs.(df[!,:dy]),abs.(df[!,:δ_y]))

    Makie.scatter!(ax3,abs.(df[!,:δ_x]),abs.(df[!,:Fx_Front]))
    Makie.lines!(ax3,abs.(df[!,:δ_x]),abs.(df[!,:Fx_Front]))


    Makie.scatter!(ax4,abs.(df[!,:δ_y]),abs.(df[!,:Fy_Front]))
    Makie.lines!(ax4,abs.(df[!,:δ_y]),abs.(df[!,:Fy_Front]))

    Makie.scatter!(ax5,abs.(df[!,:delta_y]),abs.(df[!,:Fy_Front]))
    Makie.lines!(ax5,abs.(df[!,:delta_y]),abs.(df[!,:Fy_Front]))

    Makie.scatter!(ax6,abs.(df[!,:dy]),abs.(df[!,:GI]))
    Makie.lines!(ax6,abs.(df[!,:dy]),abs.(df[!,:GI]))

    Makie.scatter!(ax7,abs.(df[!,:dy]),abs.(df[!,:GII]))
    Makie.lines!(ax7,abs.(df[!,:dy]),abs.(df[!,:GII]))
end
# Out:
# plotVCCTCurves (generic function with 1 method)

# %%
df
# Out:
# 30×36 DataFrame
#  Row │ N    Precrack  PrecrackRechts  SiAbstandRechts  SiRechts  dy   S_AlleMa ⋯
#      │ Any  Any       Any             Any              Any       Any  Any      ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 1    0.1       0.1             21.25            21.25     0.5  65.4525  ⋯
#    2 │ 2    0.1       0.1             21.25            21.25     1    131.033
#    3 │ 3    0.1       0.1             21.25            21.25     1.5  196.709
#    4 │ 4    0.1       0.1             21.25            21.25     2    262.551
#    5 │ 5    0.1       0.1             21.25            21.25     2.5  328.478  ⋯
#    6 │ 6    0.1       0.1             21.25            21.25     3    394.524
#    7 │ 7    0.3       0.3             21.25            21.25     0.5  65.3797
#    8 │ 8    0.3       0.3             21.25            21.25     1    130.892
#   ⋮  │  ⋮      ⋮            ⋮                ⋮            ⋮       ⋮       ⋮    ⋱
#   24 │ 24   0.75      0.75            21.25            21.25     3    392.428  ⋯
#   25 │ 25   1         1               21.25            21.25     0.5  64.7919
#   26 │ 26   1         1               21.25            21.25     1    129.752
#   27 │ 27   1         1               21.25            21.25     1.5  194.81
#   28 │ 28   1         1               21.25            21.25     2    259.971  ⋯
#   29 │ 29   1         1               21.25            21.25     2.5  325.25
#   30 │ 30   1         1               21.25            21.25     3    390.641
#                                                   30 columns and 15 rows omitted

# %%
width=2*1e-3 #m
delta_crack=1e-6 #m 
s_crack=width*delta_crack #m2
# Out:
# 2.0e-9

# %%
df[!,:GI]=(df[!,:Fy_Front].*(df[!,:dy_Parylene]-df[!,:dy_Si])*-1)/(2*s_crack)
df[!,:GII]=(df[!,:Fx_Front].*(df[!,:dx_Parylene]-df[!,:dx_Si])*-1)/(2*s_crack)
df[!,:δ_x]=(-df[!,:dx_Parylene]+df[!,:dx_Si])
df[!,:δ_y]=(-df[!,:dy_Parylene]+df[!,:dy_Si])
df[!,:τ_front]=df[!,:Fx_Front]*1e-6./s_crack #MPa
df[!,:σ_front]=df[!,:Fy_Front]*1e-6./s_crack #MPa
df[!,:delta_y]=(-df[!,:deltay_Parylene]+df[!,:deltay_Si]) ## Aperture in um
# Out:
# 30-element Vector{Float64}:
#  2.543674781909852e-7
#  5.101901479059997e-7
#  7.582129910599106e-7
#  9.995419531999908e-7
#  1.240288838750235e-6
#  1.4805700629901865e-6
#  4.851899575439907e-7
#  9.72999259828979e-7
#  1.4522811397899276e-6
#  1.9248109310900097e-6
#  ⋮
#  4.78792935609991e-6
#  5.975831300020218e-6
#  7.1490649133898986e-6
#  1.9112776499239964e-6
#  3.813125658780987e-6
#  5.707144737239966e-6
#  7.601571269329893e-6
#  9.486451745030228e-6
#  1.1357944458720032e-5

# %%
df
# Out:
# 30×43 DataFrame
#  Row │ N    Precrack  PrecrackRechts  SiAbstandRechts  SiRechts  dy   S_AlleMa ⋯
#      │ Any  Any       Any             Any              Any       Any  Any      ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 1    0.1       0.1             21.25            21.25     0.5  65.4525  ⋯
#    2 │ 2    0.1       0.1             21.25            21.25     1    131.033
#    3 │ 3    0.1       0.1             21.25            21.25     1.5  196.709
#    4 │ 4    0.1       0.1             21.25            21.25     2    262.551
#    5 │ 5    0.1       0.1             21.25            21.25     2.5  328.478  ⋯
#    6 │ 6    0.1       0.1             21.25            21.25     3    394.524
#    7 │ 7    0.3       0.3             21.25            21.25     0.5  65.3797
#    8 │ 8    0.3       0.3             21.25            21.25     1    130.892
#   ⋮  │  ⋮      ⋮            ⋮                ⋮            ⋮       ⋮       ⋮    ⋱
#   24 │ 24   0.75      0.75            21.25            21.25     3    392.428  ⋯
#   25 │ 25   1         1               21.25            21.25     0.5  64.7919
#   26 │ 26   1         1               21.25            21.25     1    129.752
#   27 │ 27   1         1               21.25            21.25     1.5  194.81
#   28 │ 28   1         1               21.25            21.25     2    259.971  ⋯
#   29 │ 29   1         1               21.25            21.25     2.5  325.25
#   30 │ 30   1         1               21.25            21.25     3    390.641
#                                                   37 columns and 15 rows omitted

# %%
df_dy1=Float64.(filter_range(df,"dy",1))
# Out:
# 5×43 DataFrame
#  Row │ N        Precrack  PrecrackRechts  SiAbstandRechts  SiRechts  dy        ⋯
#      │ Float64  Float64   Float64         Float64          Float64   Float64   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │     2.0      0.1             0.1             21.25     21.25      1.0   ⋯
#    2 │     8.0      0.3             0.3             21.25     21.25      1.0
#    3 │    14.0      0.5             0.5             21.25     21.25      1.0
#    4 │    20.0      0.75            0.75            21.25     21.25      1.0
#    5 │    26.0      1.0             1.0             21.25     21.25      1.0   ⋯
#                                                               37 columns omitted

# %%
using Interpolations

# %%
a=df_dy1."Precrack"
# Out:
# 5-element Vector{Float64}:
#  0.1
#  0.3
#  0.5
#  0.75
#  1.0

# %%
a=df_dy1."Precrack"
G=-df_dy1."GII"
# Out:
# 5-element Vector{Float64}:
#  -0.12071026681440258
#  -0.19510535217547575
#  -0.23674110539906004
#  -0.3091478939946105
#  -0.32688693889382947

# %%
G=df_dy1."GI"
# Out:
# 5-element Vector{Float64}:
#  1.7371617995553617
#  2.246977553264452
#  3.3545973596724847
#  4.718890443718056
#  7.677431464116357

# %%
a
# Out:
# 5-element Vector{Float64}:
#  0.1
#  0.3
#  0.5
#  0.75
#  1.0

# %%
using Interpolations

# %%
itp = interpolate((a,), G, Gridded(Linear()))
val = itp(0.1)
# Out:
# 1.7371617995553617

# %% [markdown]
# ## Pre crack 10 50 100 200 300 500

# %%
for i in [ 0.1, 0.3, 0.5, 0.75, 1]

    df_filter=Float64.(filter_range(df,"Precrack",i))
    plotBendingCurves(ax1_1,ax2_1,ax3_1,ax4_1,ax5_1,df_filter)
    plotVCCTCurves(ax1_2,ax2_2,ax3_2,ax4_2,ax5_2,ax6_2,ax7_2,df_filter)
end

# %%
fig

# %%
fig2

# %% [markdown]
# ## Experimental Fatigue AP5F10

# %%
function importTest(path)

    #file = XLSX.readxlsx(path)
    df=CSV.read(path,DataFrame) 
    
    for col in names(df)
        if eltype(df[!, col]) <: AbstractString
           
                df[!, col] = parse.(Float64, replace.(df[!, col], "," => "."))
                # skip columns that cannot be converted
            
        end#
    
    end

    return df
end
# Out:
# importTest (generic function with 1 method)

# %%
df_exp=df= XLSX.readtable("AP5MEF02_Fatigue.xlsx", "Sheet1") |> DataFrame
# Out:
# 12×10 DataFrame
#  Row │ Name        Sample  a    d    f    a0Links  a0Rechts  afLinks  afRechts ⋯
#      │ Any         Any     Any  Any  Any  Any      Any       Any      Any      ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 260108-1_A  A       1.2  25   1.2  108.669  0         126      21.52    ⋯
#    2 │ 260108-1_B  B       1.2  25   1.2  30.361   24.25     30.98    32.87
#    3 │ 260108-2_A  A       1.2  25   1.2  31.12    21.98     34.86    27.73
#    4 │ 260108-2_B  B       1.2  25   1.2  110.08   14.9      110.83   28.54
#    5 │ 260109-1_A  A       1.2  25   1.2  65.19    31.89     75.8     40.6     ⋯
#    6 │ 260109-1_B  B       1.2  25   1.2  150.76   39.23     148.6    52.66
#    7 │ 260109-2_A  A       1.2  25   1.2  53.5     43.34     35.3     54.66
#    8 │ 260109-2_B  B       1.2  25   1.2  0        0         0        0
#    9 │ 260109-1_A  A       1.2  25   1.2  65.19    31.89     87.57    45.85    ⋯
#   10 │ 260109-1_B  B       1.2  25   1.2  150.76   39.23     143.46   49.68
#   11 │ 260109-2_A  A       1.2  25   1.2  53.5     43.34     90       77.1258
#   12 │ 260109-2_B  B       1.2  25   1.2  0        0         103.28   87.29
#                                                                 1 column omitted

# %%
df_exp[!,:aLinks]=400 .+ df_exp[!,:afLinks]
df_exp[!,:aRechts]=400 .+ df_exp[!,:afRechts]
# Out:
# 12-element Vector{Real}:
#  421.52
#  432.87
#  427.73
#  428.54
#  440.6
#  452.65999999999997
#  454.65999999999997
#  400
#  445.85
#  449.68
#  477.1258
#  487.29

# %%
df_exp
# Out:
# 12×12 DataFrame
#  Row │ Name        Sample  a    d    f    a0Links  a0Rechts  afLinks  afRechts ⋯
#      │ Any         Any     Any  Any  Any  Any      Any       Any      Any      ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 260108-1_A  A       1.2  25   1.2  108.669  0         126      21.52    ⋯
#    2 │ 260108-1_B  B       1.2  25   1.2  30.361   24.25     30.98    32.87
#    3 │ 260108-2_A  A       1.2  25   1.2  31.12    21.98     34.86    27.73
#    4 │ 260108-2_B  B       1.2  25   1.2  110.08   14.9      110.83   28.54
#    5 │ 260109-1_A  A       1.2  25   1.2  65.19    31.89     75.8     40.6     ⋯
#    6 │ 260109-1_B  B       1.2  25   1.2  150.76   39.23     148.6    52.66
#    7 │ 260109-2_A  A       1.2  25   1.2  53.5     43.34     35.3     54.66
#    8 │ 260109-2_B  B       1.2  25   1.2  0        0         0        0
#    9 │ 260109-1_A  A       1.2  25   1.2  65.19    31.89     87.57    45.85    ⋯
#   10 │ 260109-1_B  B       1.2  25   1.2  150.76   39.23     143.46   49.68
#   11 │ 260109-2_A  A       1.2  25   1.2  53.5     43.34     90       77.1258
#   12 │ 260109-2_B  B       1.2  25   1.2  0        0         103.28   87.29
#                                                                3 columns omitted

# %%
delete!(df_exp,8)
# Out:
# 11×12 DataFrame
#  Row │ Name        Sample  a    d    f    a0Links  a0Rechts  afLinks  afRechts ⋯
#      │ Any         Any     Any  Any  Any  Any      Any       Any      Any      ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 260108-1_A  A       1.2  25   1.2  108.669  0         126      21.52    ⋯
#    2 │ 260108-1_B  B       1.2  25   1.2  30.361   24.25     30.98    32.87
#    3 │ 260108-2_A  A       1.2  25   1.2  31.12    21.98     34.86    27.73
#    4 │ 260108-2_B  B       1.2  25   1.2  110.08   14.9      110.83   28.54
#    5 │ 260109-1_A  A       1.2  25   1.2  65.19    31.89     75.8     40.6     ⋯
#    6 │ 260109-1_B  B       1.2  25   1.2  150.76   39.23     148.6    52.66
#    7 │ 260109-2_A  A       1.2  25   1.2  53.5     43.34     35.3     54.66
#    8 │ 260109-1_A  A       1.2  25   1.2  65.19    31.89     87.57    45.85
#    9 │ 260109-1_B  B       1.2  25   1.2  150.76   39.23     143.46   49.68    ⋯
#   10 │ 260109-2_A  A       1.2  25   1.2  53.5     43.34     90       77.1258
#   11 │ 260109-2_B  B       1.2  25   1.2  0        0         103.28   87.29
#                                                                3 columns omitted

# %%
delete!(df_exp,1)
# Out:
# 7×12 DataFrame
#  Row │ Name        Sample  a    d    f    a0Links  a0Rechts  afLinks  afRechts ⋯
#      │ Any         Any     Any  Any  Any  Any      Any       Any      Any      ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 260109-1_A  A       1.2  25   1.2  65.19    31.89     75.8     40.6     ⋯
#    2 │ 260109-1_B  B       1.2  25   1.2  150.76   39.23     148.6    52.66
#    3 │ 260109-2_A  A       1.2  25   1.2  53.5     43.34     35.3     54.66
#    4 │ 260109-1_A  A       1.2  25   1.2  65.19    31.89     87.57    45.85
#    5 │ 260109-1_B  B       1.2  25   1.2  150.76   39.23     143.46   49.68    ⋯
#    6 │ 260109-2_A  A       1.2  25   1.2  53.5     43.34     90       77.1258
#    7 │ 260109-2_B  B       1.2  25   1.2  0        0         103.28   87.29
#                                                                3 columns omitted

# %%
df_exp[!,:delta_aLinks]= df_exp[!,:afLinks] -df_exp[!,:a0Links]
df_exp[!,:delta_aRechts]= df_exp[!,:afRechts] -df_exp[!,:a0Rechts]
# Out:
# 7-element Vector{Float64}:
#   8.71
#  13.43
#  11.319999999999993
#  13.96
#  10.450000000000003
#  33.785799999999995
#  87.29

# %%
df_exp[!,:dadNLinks]= df_exp[!,:delta_aLinks]./df_exp[!,:N]
df_exp[!,:dadNRechts]= df_exp[!,:delta_aRechts]./df_exp[!,:N]
# Out:
# 7-element Vector{Float64}:
#  0.0001742
#  0.00026859999999999997
#  0.00022639999999999987
#  0.00018613333333333335
#  0.00013933333333333338
#  0.0004504773333333333
#  0.0011638666666666667

# %%
df_exp
# Out:
# 7×16 DataFrame
#  Row │ Name        Sample  a    d    f    a0Links  a0Rechts  afLinks  afRechts ⋯
#      │ Any         Any     Any  Any  Any  Any      Any       Any      Any      ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 260109-1_A  A       1.2  25   1.2  65.19    31.89     75.8     40.6     ⋯
#    2 │ 260109-1_B  B       1.2  25   1.2  150.76   39.23     148.6    52.66
#    3 │ 260109-2_A  A       1.2  25   1.2  53.5     43.34     35.3     54.66
#    4 │ 260109-1_A  A       1.2  25   1.2  65.19    31.89     87.57    45.85
#    5 │ 260109-1_B  B       1.2  25   1.2  150.76   39.23     143.46   49.68    ⋯
#    6 │ 260109-2_A  A       1.2  25   1.2  53.5     43.34     90       77.1258
#    7 │ 260109-2_B  B       1.2  25   1.2  0        0         103.28   87.29
#                                                                7 columns omitted

# %%
df_N30 = df[coalesce.(df."N" .== 30000, false), :]
df_N50 = df[coalesce.(df."N" .== 50000, false), :]
df_N75 = df[coalesce.(df."N" .== 75000, false), :]
# Out:
# 4×16 DataFrame
#  Row │ Name        Sample  a    d    f    a0Links  a0Rechts  afLinks  afRechts ⋯
#      │ Any         Any     Any  Any  Any  Any      Any       Any      Any      ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 260109-1_A  A       1.2  25   1.2  65.19    31.89     87.57    45.85    ⋯
#    2 │ 260109-1_B  B       1.2  25   1.2  150.76   39.23     143.46   49.68
#    3 │ 260109-2_A  A       1.2  25   1.2  53.5     43.34     90       77.1258
#    4 │ 260109-2_B  B       1.2  25   1.2  0        0         103.28   87.29
#                                                                7 columns omitted

# %%
GI_exp=Float64[]
# Out:
# Float64[]

# %%
df_exp."aRechts"
# Out:
# 7-element Vector{Real}:
#  440.6
#  452.65999999999997
#  454.65999999999997
#  445.85
#  449.68
#  477.1258
#  487.29

# %%
for i in df_exp."aRechts"
    push!(GI_exp,itp(i/1000))

end

# %%
GI_exp
# Out:
# 7-element Vector{Float64}:
#  3.0256342771692992
#  3.092423751495703
#  3.1034999495597835
#  3.05470929708751
#  3.075920216380224
#  3.2279177747937915
#  3.2842081209752543

# %%
dadN=df_exp."dadNRechts"
# Out:
# 7-element Vector{Float64}:
#  0.0001742
#  0.00026859999999999997
#  0.00022639999999999987
#  0.00018613333333333335
#  0.00013933333333333338
#  0.0004504773333333333
#  0.0011638666666666667

# %%
dadN
# Out:
# 7-element Vector{Float64}:
#  0.0001742
#  0.00026859999999999997
#  0.00022639999999999987
#  0.00018613333333333335
#  0.00013933333333333338
#  0.0004504773333333333
#  0.0011638666666666667

# %%
font = 36
fig = Figure(resolution = (1000, 600))

axf = Axis(fig[1, 1],
    xlabel = L"\Delta G~(\mathrm{J/m^2})",
    ylabel = L"\frac{da}{dN}~(\mu\mathrm{m/cycle})",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridvisible = false,   # kein vertikales Grid
    ygridvisible = false 

)
# Out:
# Axis with 0 plots:

# %%
log10.(GI_exp)
# Out:
# 7-element Vector{Float64}:
#  0.48081643161636584
#  0.4902990002290779
#  0.49185174266296317
#  0.48496988669709
#  0.4879750664885664
#  0.5089224633461455
#  0.5164306706542172

# %%
log10.(dadN)
# Out:
# 7-element Vector{Float64}:
#  -3.758951849328356
#  -3.5708939916673037
#  -3.6451235774837665
#  -3.730175845104558
#  -3.855944972944627
#  -3.3463270565293417
#  -2.9340967698989004

# %%
Makie.scatter!(axf, log10.(GI_exp), log10.(dadN);
                    marker = :utriangle,
                    markersize = 28,
                    color = :black)
# Out:
# Scatter{Tuple{Vector{Point{2, Float32}}}}

# %%
fig

# %%
df = DataFrame(ΔG = GII_exp , dadN = dadN)
# Out:
# 5×2 DataFrame
#  Row │ ΔG       dadN
#      │ Float64  Float64
# ─────┼─────────────────────
#    1 │ 8.98658  0.0007582
#    2 │ 8.56159  0.0003407
#    3 │ 9.24458  0.00145845
#    4 │ 9.18479  0.00170205
#    5 │ 9.0619   0.0008882

# %%
CSV.write("SI_PY_AP5F10.csv", df)
# Out:
# "SI_PY_AP5F10.csv"
