# %%
using Pkg
using CSV
using DataFrames
using Polynomials
using CairoMakie
using Statistics

# %%
include("D:/01 Projekt/03 Programm/Rini aktuell/Rini/src/TIRA.jl")
# Out:
# WARNING: replacing module TIRA.
# Main.TIRA

# %% [markdown]
# ## Plots

# %% [markdown]
# ## Proben Geometrie

# %%
## Geometrie
w=10*1e-3 # Width
t=15.5*1e-6 # thickness W3 from the 2nd batch
l=60*1e-3 # length between clamps
As=w*t    # stress section
# Out:
# 1.55e-7

# %% [markdown]
# ## Raum Temperature

# %%
BaseName="AP5ZMEF01-2/260126-"
name="260126-"
file_path = "$(BaseName)$(2).csv"
# Out:
# "AP5ZMEF01-2/260126-2.csv"

# %%
df_260126=[]
# Out:
# Any[]

# %%
DataProperties=[]
# Out:
# Any[]

# %%
#### Raum T


# Plot the first curve with lines and markers
figRaum = Figure(resolution = (1000, 600))
font=24
ax1_Raum = Axis(figRaum[1,1],
    xlabel = L"Weg (mm)",
    ylabel = L"\sigma (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)

ax2_Raum = Axis(figRaum[1,2],
    xlabel = L"\epsilon (%)",
    ylabel = L"\sigma (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)

ax3_Raum = Axis(figRaum[1,3],
    xlabel = L"t (s)",
    ylabel = L"ϵ (%)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)


## Filter Data


for i in [1 2]
        
        df=TIRA.computeStressStrain(BaseName,name,i,22,As)
        df=TIRA.filter_range(df,"Weg",0,5)

        Makie.scatter!(ax1_Raum ,df[!,:Weg],df[!,:Stress];
        markersize=14, 
        label = "T22 $(name)$(i)")


        Makie.scatter!(ax2_Raum ,df[!,:Strain],df[!,:Stress];
        markersize=14, 
        label = "T22 $(name)$(i)")
        limits!(ax2_Raum, 0, 4, 0, 70)

    
        Makie.lines!(ax3_Raum ,df[!,:Zeit],df[!,:Strain];
        
        label = "strain rate $(name)$(i)")
        limits!(ax3_Raum, 0, 100, 0, 5)
        #limits!(ax3_Raum, 0.1, 1,0,30)
        
end

df_DataProperties=DataFrame(DataProperties)

axislegend(ax1_Raum, labelsize=font-10, framevisible=false,position = :rb)
axislegend(ax2_Raum, labelsize=font-10, framevisible=false,position = :rb)
axislegend(ax3_Raum, labelsize=font-10, framevisible=false,position = :rb)
figRaum

# %%
ϵ_LinearRange=[0.1 1]
ϵ_range=[0 4]
t_range=[0 100] #in order to avoid wrong measurements from the camera
σ_range=[0 80]
T=22
# Out:
# 22

# %%
#### Raum T
# Plot the first curve with lines and markers
figRaum = Figure(resolution = (1000, 600))
font=24
ax1_Raum = Axis(figRaum[1,1],
    xlabel = L"\epsilon (%)",
    ylabel = L"\sigma (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)

ax2_Raum = Axis(figRaum[1,2],
    xlabel = L"\epsilon (%)",
    ylabel = L"\sigma (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)



DataProperties=[]

for i in [1 2]
        
        df=TIRA.computeStressStrain(BaseName,name,i,T,As)
        df=TIRA.filter_range(df,"Zeit",t_range[1],t_range[2])
        df=TIRA.filter_range(df,"dL_ORG",ϵ_range[1],ϵ_range[2])

        properties, df_fit=TIRA.computeProperties(df,ϵ_LinearRange,σ_range)
        
        df_Properties=DataFrame(properties)

        Makie.scatter!(ax1_Raum ,df[!,:Strain],df[!,:Stress];
        markersize=14, 
        label = "T$(T), v=$(round(df_Properties[1," Strain Rate[%/min]"], digits=3)) %/min")
        
        
        limits!(ax1_Raum, 0, 5, 0, 75)


        Makie.scatter!(ax2_Raum ,df[!,:Strain],df[!,:Stress];
        markersize=14, 
        label = "T$(T), v=$(round(df_Properties[1," Strain Rate[%/min]"], digits=3)) %/min")

        Makie.lines!(ax2_Raum ,df_fit[!,:Strain],df_fit[!,:StressFit];
        color = :black, 
        label = "Fit")
        limits!(ax2_Raum, 0.1, 1,0,50)

        push!(DataProperties,properties)
        
end

df_DataProperties=DataFrame(DataProperties)

axislegend(ax1_Raum, labelsize=font-10, framevisible=false,position = :rb)
axislegend(ax2_Raum, labelsize=font-10, framevisible=false,position = :rb)

figRaum

# %%
df_DataProperties
# Out:
# 2×11 DataFrame
#  Row │ e_max[%]  δ_F/δ_B  Probe     δ_B      LinearRange [%]  u_E[%]    Temper ⋯
#      │ Float64   Float64  String    Float64  Vector{Float64}  Float64   Int64  ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 26.528    37.1747  260126-1     2.69  [0.11, 1.0]      0.433918         ⋯
#    2 │  5.59948  39.6825  260126-2     2.52  [0.1, 1.0]       0.259061
#                                                                5 columns omitted

# %% [markdown]
# ## Temperatur 40

# %%
BaseName="AP5ZMEF01-2/260126-"
name="260126-"
file_path = "$(BaseName)$(2).csv"
# Out:
# "AP5ZMEF01-2/260126-2.csv"

# %%
df_260126=[]
# Out:
# Any[]

# %%
#### T40


# Plot the first curve with lines and markers
figRaum = Figure(resolution = (1000, 600))
font=24
ax1_Raum = Axis(figRaum[1,1],
    xlabel = L"Weg (mm)",
    ylabel = L"\sigma (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)

ax2_Raum = Axis(figRaum[1,2],
    xlabel = L"\epsilon (%)",
    ylabel = L"\sigma (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)

ax3_Raum = Axis(figRaum[1,3],
    xlabel = L"t (s)",
    ylabel = L"ϵ (%)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)


## Filter Data


for i in [3 4 5 6]
        
        df=TIRA.computeStressStrain(BaseName,name,i,22,As)
        df=TIRA.filter_range(df,"Weg",0,5)

        Makie.scatter!(ax1_Raum ,df[!,:Weg],df[!,:Stress];
        markersize=14, 
        label = "T40 $(name)$(i)")


        Makie.scatter!(ax2_Raum ,df[!,:Strain],df[!,:Stress];
        markersize=14, 
        label = "T40 $(name)$(i)")
        limits!(ax2_Raum, 0, 4, 0, 70)

    
        Makie.lines!(ax3_Raum ,df[!,:Zeit],df[!,:Strain];
        
        label = "strain rate $(name)$(i)")
        limits!(ax3_Raum, 0, 100, 0, 5)
        #limits!(ax3_Raum, 0.1, 1,0,30)
        
end

df_DataProperties=DataFrame(DataProperties)

axislegend(ax1_Raum, labelsize=font-10, framevisible=false,position = :rb)
axislegend(ax2_Raum, labelsize=font-10, framevisible=false,position = :rb)
axislegend(ax3_Raum, labelsize=font-10, framevisible=false,position = :rb)
figRaum

# %%
ϵ_LinearRange=[0.5 1]
ϵ_range=[0 4]
t_range=[0 100] #in order to avoid wrong measurements from the camera
σ_range=[0 50]
T=40
# Out:
# 40

# %%
#### Raum T
# Plot the first curve with lines and markers
figRaum = Figure(resolution = (1000, 600))
font=24
ax1_Raum = Axis(figRaum[1,1],
    xlabel = L"\epsilon (%)",
    ylabel = L"\sigma (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)

ax2_Raum = Axis(figRaum[1,2],
    xlabel = L"\epsilon (%)",
    ylabel = L"\sigma (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)



for i in [3 4 5 6]
        
        df=TIRA.computeStressStrain(BaseName,name,i,T,As)
        df=TIRA.filter_range(df,"Zeit",t_range[1],t_range[2])
        df=TIRA.filter_range(df,"dL_ORG",ϵ_range[1],ϵ_range[2])

        properties, df_fit=TIRA.computeProperties(df,ϵ_LinearRange,σ_range)
        
        df_Properties=DataFrame(properties)

        Makie.scatter!(ax1_Raum ,df[!,:Strain],df[!,:Stress];
        markersize=14, 
        label = "T$(T), v=$(round(df_Properties[1," Strain Rate[%/min]"], digits=3)) %/min")
        
        
        limits!(ax1_Raum, 0, 4, 0, 50)


        Makie.scatter!(ax2_Raum ,df[!,:Strain],df[!,:Stress];
        markersize=14, 
        label = "T$(T), v=$(round(df_Properties[1," Strain Rate[%/min]"], digits=3)) %/min")

        Makie.lines!(ax2_Raum ,df_fit[!,:Strain],df_fit[!,:StressFit];
        color = :black, 
        label = "Fit")
        limits!(ax2_Raum, 0.1, 1,0,30)

        push!(DataProperties,properties)
        
end

df_DataProperties=DataFrame(DataProperties)

axislegend(ax1_Raum, labelsize=font-10, framevisible=false,position = :rb)
axislegend(ax2_Raum, labelsize=font-10, framevisible=false,position = :rb)

figRaum

# %%
df_DataProperties
# Out:
# 6×11 DataFrame
#  Row │ e_max[%]  δ_F/δ_B  Probe     δ_B      LinearRange [%]  u_E[%]    Temper ⋯
#      │ Float64   Float64  String    Float64  Vector{Float64}  Float64   Int64  ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 26.528    37.1747  260126-1     2.69  [0.11, 1.0]      0.433918         ⋯
#    2 │  5.59948  39.6825  260126-2     2.52  [0.1, 1.0]       0.259061
#    3 │  4.29725  51.5464  260126-3     1.94  [0.5, 1.0]       0.108925
#    4 │  2.48575  55.8659  260126-4     1.79  [0.5, 1.0]       0.174795
#    5 │  1.99845  54.9451  260126-5     1.82  [0.5, 1.0]       0.27083          ⋯
#    6 │  5.79402  53.4759  260126-6     1.87  [0.5, 1.0]       0.582814
#                                                                5 columns omitted

# %% [markdown]
# ## Temperatur 50

# %%
BaseName="AP5ZMEF01-2/260126-"
name="260126-"
file_path = "$(BaseName)$(2).csv"
# Out:
# "AP5ZMEF01-2/260126-2.csv"

# %%
df_260126=[]
# Out:
# Any[]

# %%
aktuellProperties=[]
# Out:
# Any[]

# %%
#### T50


# Plot the first curve with lines and markers
figRaum = Figure(resolution = (1000, 600))
font=24
ax1_Raum = Axis(figRaum[1,1],
    xlabel = L"Weg (mm)",
    ylabel = L"\sigma (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)

ax2_Raum = Axis(figRaum[1,2],
    xlabel = L"\epsilon (%)",
    ylabel = L"\sigma (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)

ax3_Raum = Axis(figRaum[1,3],
    xlabel = L"t (s)",
    ylabel = L"ϵ (%)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)


## Filter Data


for i in [7 8]
        
        df=TIRA.computeStressStrain(BaseName,name,i,22,As)
        df=TIRA.filter_range(df,"Weg",0,5)

        Makie.scatter!(ax1_Raum ,df[!,:Weg],df[!,:Stress];
        markersize=14, 
        label = "T40 $(name)$(i)")


        Makie.scatter!(ax2_Raum ,df[!,:Strain],df[!,:Stress];
        markersize=14, 
        label = "T40 $(name)$(i)")
        limits!(ax2_Raum, 0, 4, 0, 70)

    
        Makie.lines!(ax3_Raum ,df[!,:Zeit],df[!,:Strain];
        
        label = "strain rate $(name)$(i)")
        limits!(ax3_Raum, 0, 1000, 0, 5)
        #limits!(ax3_Raum, 0.1, 1,0,30)
        
end

df_DataProperties=DataFrame(DataProperties)

axislegend(ax1_Raum, labelsize=font-10, framevisible=false,position = :rb)
axislegend(ax2_Raum, labelsize=font-10, framevisible=false,position = :rb)
axislegend(ax3_Raum, labelsize=font-10, framevisible=false,position = :rb)
figRaum

# %%
ϵ_LinearRange=[0.2 0.8]
ϵ_range=[0 4]
t_range=[0 1000] #in order to avoid wrong measurements from the camera
σ_range=[0 30]
T=50
aktuellProperties=[]
# Out:
# Any[]

# %%
#### Raum T
# Plot the first curve with lines and markers
figRaum = Figure(resolution = (1000, 600))
font=24
ax1_Raum = Axis(figRaum[1,1],
    xlabel = L"\epsilon (%)",
    ylabel = L"\sigma (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)

ax2_Raum = Axis(figRaum[1,2],
    xlabel = L"\epsilon (%)",
    ylabel = L"\sigma (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)



for i in [7 8]
        
        df=TIRA.computeStressStrain(BaseName,name,i,T,As)
        df=TIRA.filter_range(df,"Zeit",t_range[1],t_range[2])
        df=TIRA.filter_range(df,"dL_ORG",ϵ_range[1],ϵ_range[2])

        properties, df_fit=TIRA.computeProperties(df,ϵ_LinearRange,σ_range)
        
        df_Properties=DataFrame(properties)

        Makie.scatter!(ax1_Raum ,df[!,:Strain],df[!,:Stress];
        markersize=14, 
        label = "T$(T), v=$(round(df_Properties[1," Strain Rate[%/min]"], digits=3)) %/min")
        
        limits!(ax1_Raum, ϵ_range[1],ϵ_range[2], σ_range[1],σ_range[2])


        Makie.scatter!(ax2_Raum ,df[!,:Strain],df[!,:Stress];
        markersize=14, 
        label = "T$(T), v=$(round(df_Properties[1," Strain Rate[%/min]"], digits=3)) %/min")

        Makie.lines!(ax2_Raum ,df_fit[!,:Strain],df_fit[!,:StressFit];
        color = :black, 
        label = "Fit")
        limits!(ax2_Raum, ϵ_LinearRange[1], ϵ_LinearRange[2], σ_range[1],σ_range[2])

        push!(aktuellProperties,properties)
        
end

df_aktuellProperties=DataFrame(aktuellProperties)

axislegend(ax1_Raum, labelsize=font-10, framevisible=false,position = :rb)
axislegend(ax2_Raum, labelsize=font-10, framevisible=false,position = :rb)

figRaum

# %%
df_aktuellProperties
# Out:
# 2×11 DataFrame
#  Row │ e_max[%]  δ_F/δ_B  Probe     δ_B      LinearRange [%]  u_E[%]     Tempe ⋯
#      │ Float64   Float64  String    Float64  Vector{Float64}  Float64    Int64 ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │  4.7615   34.4828  260126-7     2.32  [0.2, 0.8]       0.0955177        ⋯
#    2 │  9.09536  31.1284  260126-8     2.57  [0.2, 0.8]       0.111459
#                                                                5 columns omitted

# %%
push!(DataProperties,aktuellProperties[1])
push!(DataProperties,aktuellProperties[2])
# Out:
# 8-element Vector{Any}:
#  Dict{String, Any}("e_max[%]" => 26.527986989324255, "δ_F/δ_B" => 37.17472118959108, "Probe" => "260126-1", "δ_B" => 2.69, "LinearRange [%]" => [0.11, 1.0], "u_E[%] " => 0.43391837312932485, "Temperature [C]" => 22, "E[GPa] " => 3.5792303678701494, "sigmaMax" => 59.677419354838705, "sigma0_25% " => 29.225806451612904…)
#  Dict{String, Any}("e_max[%]" => 5.599483284541063, "δ_F/δ_B" => 39.682539682539684, "Probe" => "260126-2", "δ_B" => 2.52, "LinearRange [%]" => [0.1, 1.0], "u_E[%] " => 0.2590609396773203, "Temperature [C]" => 22, "E[GPa] " => 3.4017543510437074, "sigmaMax" => 63.29032258064516, "sigma0_25% " => 37.16129032258065…)
#  Dict{String, Any}("e_max[%]" => 4.297253383741574, "δ_F/δ_B" => 51.54639175257732, "Probe" => "260126-3", "δ_B" => 1.94, "LinearRange [%]" => [0.5, 1.0], "u_E[%] " => 0.10892456007959146, "Temperature [C]" => 40, "E[GPa] " => 2.5055038139178634, "sigmaMax" => 33.225806451612904, "sigma0_25% " => 20.516129032258064…)
#  Dict{String, Any}("e_max[%]" => 2.4857474006002236, "δ_F/δ_B" => 55.865921787709496, "Probe" => "260126-4", "δ_B" => 1.79, "LinearRange [%]" => [0.5, 1.0], "u_E[%] " => 0.17479501590924829, "Temperature [C]" => 40, "E[GPa] " => 3.0429662077211335, "sigmaMax" => 38.12903225806452, "sigma0_25% " => 30.96774193548387…)
#  Dict{String, Any}("e_max[%]" => 1.998452703357493, "δ_F/δ_B" => 54.94505494505494, "Probe" => "260126-5", "δ_B" => 1.82, "LinearRange [%]" => [0.5, 1.0], "u_E[%] " => 0.2708295533851108, "Temperature [C]" => 40, "E[GPa] " => 2.7190772665381147, "sigmaMax" => 43.29032258064516, "sigma0_25% " => 31.612903225806456…)
#  Dict{String, Any}("e_max[%]" => 5.794019154106645, "δ_F/δ_B" => 53.475935828877, "Probe" => "260126-6", "δ_B" => 1.87, "LinearRange [%]" => [0.5, 1.0], "u_E[%] " => 0.582814461026427, "Temperature [C]" => 40, "E[GPa] " => 2.793102883328682, "sigmaMax" => 42.12903225806452, "sigma0_25% " => 31.548387096774192…)
#  Dict{String, Any}("e_max[%]" => 4.7614998549699274, "δ_F/δ_B" => 34.48275862068966, "Probe" => "260126-7", "δ_B" => 2.32, "LinearRange [%]" => [0.2, 0.8], "u_E[%] " => 0.09551772445256607, "Temperature [C]" => 50, "E[GPa] " => 2.019768517944045, "sigmaMax" => 27.548387096774192, "sigma0_25% " => 17.67741935483871…)
#  Dict{String, Any}("e_max[%]" => 9.095361152674457, "δ_F/δ_B" => 31.128404669260703, "Probe" => "260126-8", "δ_B" => 2.57, "LinearRange [%]" => [0.2, 0.8], "u_E[%] " => 0.1114587717447636, "Temperature [C]" => 50, "E[GPa] " => 1.9333025088918983, "sigmaMax" => 29.03225806451613, "sigma0_25% " => 16.64516129032258…)

# %%
df_DataProperties=DataFrame(DataProperties)
# Out:
# 8×11 DataFrame
#  Row │ e_max[%]  δ_F/δ_B  Probe     δ_B      LinearRange [%]  u_E[%]     Tempe ⋯
#      │ Float64   Float64  String    Float64  Vector{Float64}  Float64    Int64 ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 26.528    37.1747  260126-1     2.69  [0.11, 1.0]      0.433918         ⋯
#    2 │  5.59948  39.6825  260126-2     2.52  [0.1, 1.0]       0.259061
#    3 │  4.29725  51.5464  260126-3     1.94  [0.5, 1.0]       0.108925
#    4 │  2.48575  55.8659  260126-4     1.79  [0.5, 1.0]       0.174795
#    5 │  1.99845  54.9451  260126-5     1.82  [0.5, 1.0]       0.27083          ⋯
#    6 │  5.79402  53.4759  260126-6     1.87  [0.5, 1.0]       0.582814
#    7 │  4.7615   34.4828  260126-7     2.32  [0.2, 0.8]       0.0955177
#    8 │  9.09536  31.1284  260126-8     2.57  [0.2, 0.8]       0.111459
#                                                                5 columns omitted

# %% [markdown]
# ## Temperatur 60

# %%
BaseName="AP5ZMEF01-2/260126-"
name="260126-"
file_path = "$(BaseName)$(2).csv"
# Out:
# "AP5ZMEF01-2/260126-2.csv"

# %%
df_260126=[]
# Out:
# Any[]

# %%
aktuellProperties=[]
# Out:
# Any[]

# %%
#### T50


# Plot the first curve with lines and markers
figRaum = Figure(resolution = (1000, 600))
font=24
ax1_Raum = Axis(figRaum[1,1],
    xlabel = L"Weg (mm)",
    ylabel = L"\sigma (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)

ax2_Raum = Axis(figRaum[1,2],
    xlabel = L"\epsilon (%)",
    ylabel = L"\sigma (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)

ax3_Raum = Axis(figRaum[1,3],
    xlabel = L"t (s)",
    ylabel = L"ϵ (%)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)


## Filter Data


for i in [ 9 10 11]
        
        df=TIRA.computeStressStrain(BaseName,name,i,22,As)
        df=TIRA.filter_range(df,"Weg",0,5)

        Makie.scatter!(ax1_Raum ,df[!,:Weg],df[!,:Stress];
        markersize=14, 
        label = "T60 $(name)$(i)")


        Makie.scatter!(ax2_Raum ,df[!,:Strain],df[!,:Stress];
        markersize=14, 
        label = "T60 $(name)$(i)")
        limits!(ax2_Raum, 0, 4, 0, 70)

    
        Makie.lines!(ax3_Raum ,df[!,:Zeit],df[!,:Strain];
        
        label = "strain rate $(name)$(i)")
        limits!(ax3_Raum, 0, 1000, 0, 5)
        #limits!(ax3_Raum, 0.1, 1,0,30)
        
end

df_DataProperties=DataFrame(DataProperties)

axislegend(ax1_Raum, labelsize=font-10, framevisible=false,position = :rb)
axislegend(ax2_Raum, labelsize=font-10, framevisible=false,position = :rb)
axislegend(ax3_Raum, labelsize=font-10, framevisible=false,position = :rb)
figRaum

# %%
ϵ_LinearRange=[0.5 1]
ϵ_range=[0 2]
t_range=[0 1000] #in order to avoid wrong measurements from the camera
σ_range=[0 35]
T=60
aktuellProperties=[]
# Out:
# Any[]

# %%
#### Raum T
# Plot the first curve with lines and markers
figRaum = Figure(resolution = (1000, 600))
font=24
ax1_Raum = Axis(figRaum[1,1],
    xlabel = L"\epsilon (%)",
    ylabel = L"\sigma (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)

ax2_Raum = Axis(figRaum[1,2],
    xlabel = L"\epsilon (%)",
    ylabel = L"\sigma (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)



for i in [9 10 11]
        
        df=TIRA.computeStressStrain(BaseName,name,i,T,As)
        df=TIRA.filter_range(df,"Zeit",t_range[1],t_range[2])
        df=TIRA.filter_range(df,"dL_ORG",ϵ_range[1],ϵ_range[2])

        properties, df_fit=TIRA.computeProperties(df,ϵ_LinearRange,σ_range)
        
        df_Properties=DataFrame(properties)

        Makie.scatter!(ax1_Raum ,df[!,:Strain],df[!,:Stress];
        markersize=14, 
        label = "T$(T), v=$(round(df_Properties[1," Strain Rate[%/min]"], digits=3)) %/min")
        
        limits!(ax1_Raum, ϵ_range[1],ϵ_range[2], σ_range[1],σ_range[2])


        Makie.scatter!(ax2_Raum ,df[!,:Strain],df[!,:Stress];
        markersize=14, 
        label = "T$(T), v=$(round(df_Properties[1," Strain Rate[%/min]"], digits=3)) %/min")

        Makie.lines!(ax2_Raum ,df_fit[!,:Strain],df_fit[!,:StressFit];
        color = :black, 
        label = "Fit")
        limits!(ax2_Raum, ϵ_LinearRange[1], ϵ_LinearRange[2], σ_range[1],σ_range[2])

        push!(aktuellProperties,properties)
        
end

df_aktuellProperties=DataFrame(aktuellProperties)

axislegend(ax1_Raum, labelsize=font-10, framevisible=false,position = :rb)
axislegend(ax2_Raum, labelsize=font-10, framevisible=false,position = :rb)

figRaum

# %%
df_aktuellProperties
# Out:
# 3×11 DataFrame
#  Row │ e_max[%]  δ_F/δ_B  Probe      δ_B      LinearRange [%]  u_E[%]    Tempe ⋯
#      │ Float64   Float64  String     Float64  Vector{Float64}  Float64   Int64 ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │  2.65678  50.5051  260126-9      1.98  [0.5, 1.0]       0.133137        ⋯
#    2 │  2.46872  50.0     260126-10     2.0   [0.5, 1.0]       0.128125
#    3 │  6.63639  50.0     260126-11     2.0   [0.5, 1.0]       0.488149
#                                                                5 columns omitted

# %%
push!(DataProperties,aktuellProperties[1])
push!(DataProperties,aktuellProperties[2])
push!(DataProperties,aktuellProperties[3])
# Out:
# 11-element Vector{Any}:
#  Dict{String, Any}("e_max[%]" => 26.527986989324255, "δ_F/δ_B" => 37.17472118959108, "Probe" => "260126-1", "δ_B" => 2.69, "LinearRange [%]" => [0.11, 1.0], "u_E[%] " => 0.43391837312932485, "Temperature [C]" => 22, "E[GPa] " => 3.5792303678701494, "sigmaMax" => 59.677419354838705, "sigma0_25% " => 29.225806451612904…)
#  Dict{String, Any}("e_max[%]" => 5.599483284541063, "δ_F/δ_B" => 39.682539682539684, "Probe" => "260126-2", "δ_B" => 2.52, "LinearRange [%]" => [0.1, 1.0], "u_E[%] " => 0.2590609396773203, "Temperature [C]" => 22, "E[GPa] " => 3.4017543510437074, "sigmaMax" => 63.29032258064516, "sigma0_25% " => 37.16129032258065…)
#  Dict{String, Any}("e_max[%]" => 4.297253383741574, "δ_F/δ_B" => 51.54639175257732, "Probe" => "260126-3", "δ_B" => 1.94, "LinearRange [%]" => [0.5, 1.0], "u_E[%] " => 0.10892456007959146, "Temperature [C]" => 40, "E[GPa] " => 2.5055038139178634, "sigmaMax" => 33.225806451612904, "sigma0_25% " => 20.516129032258064…)
#  Dict{String, Any}("e_max[%]" => 2.4857474006002236, "δ_F/δ_B" => 55.865921787709496, "Probe" => "260126-4", "δ_B" => 1.79, "LinearRange [%]" => [0.5, 1.0], "u_E[%] " => 0.17479501590924829, "Temperature [C]" => 40, "E[GPa] " => 3.0429662077211335, "sigmaMax" => 38.12903225806452, "sigma0_25% " => 30.96774193548387…)
#  Dict{String, Any}("e_max[%]" => 1.998452703357493, "δ_F/δ_B" => 54.94505494505494, "Probe" => "260126-5", "δ_B" => 1.82, "LinearRange [%]" => [0.5, 1.0], "u_E[%] " => 0.2708295533851108, "Temperature [C]" => 40, "E[GPa] " => 2.7190772665381147, "sigmaMax" => 43.29032258064516, "sigma0_25% " => 31.612903225806456…)
#  Dict{String, Any}("e_max[%]" => 5.794019154106645, "δ_F/δ_B" => 53.475935828877, "Probe" => "260126-6", "δ_B" => 1.87, "LinearRange [%]" => [0.5, 1.0], "u_E[%] " => 0.582814461026427, "Temperature [C]" => 40, "E[GPa] " => 2.793102883328682, "sigmaMax" => 42.12903225806452, "sigma0_25% " => 31.548387096774192…)
#  Dict{String, Any}("e_max[%]" => 4.7614998549699274, "δ_F/δ_B" => 34.48275862068966, "Probe" => "260126-7", "δ_B" => 2.32, "LinearRange [%]" => [0.2, 0.8], "u_E[%] " => 0.09551772445256607, "Temperature [C]" => 50, "E[GPa] " => 2.019768517944045, "sigmaMax" => 27.548387096774192, "sigma0_25% " => 17.67741935483871…)
#  Dict{String, Any}("e_max[%]" => 9.095361152674457, "δ_F/δ_B" => 31.128404669260703, "Probe" => "260126-8", "δ_B" => 2.57, "LinearRange [%]" => [0.2, 0.8], "u_E[%] " => 0.1114587717447636, "Temperature [C]" => 50, "E[GPa] " => 1.9333025088918983, "sigmaMax" => 29.03225806451613, "sigma0_25% " => 16.64516129032258…)
#  Dict{String, Any}("e_max[%]" => 2.6567775877604842, "δ_F/δ_B" => 50.505050505050505, "Probe" => "260126-9", "δ_B" => 1.98, "LinearRange [%]" => [0.5, 1.0], "u_E[%] " => 0.1331371876539384, "Temperature [C]" => 60, "E[GPa] " => 1.5230441378320652, "sigmaMax" => 24.516129032258064, "sigma0_25% " => 18.96774193548387…)
#  Dict{String, Any}("e_max[%]" => 2.468715840554638, "δ_F/δ_B" => 50.0, "Probe" => "260126-10", "δ_B" => 2.0, "LinearRange [%]" => [0.5, 1.0], "u_E[%] " => 0.12812461101648345, "Temperature [C]" => 60, "E[GPa] " => 1.6780013391869322, "sigmaMax" => 24.580645161290324, "sigma0_25% " => 16.387096774193548…)
#  Dict{String, Any}("e_max[%]" => 6.636394304366348, "δ_F/δ_B" => 50.0, "Probe" => "260126-11", "δ_B" => 2.0, "LinearRange [%]" => [0.5, 1.0], "u_E[%] " => 0.4881491722876224, "Temperature [C]" => 60, "E[GPa] " => 2.059360720934584, "sigmaMax" => 29.548387096774196, "sigma0_25% " => 16.64516129032258…)

# %%
df_DataProperties=DataFrame(DataProperties)
# Out:
# 11×11 DataFrame
#  Row │ e_max[%]  δ_F/δ_B  Probe      δ_B      LinearRange [%]  u_E[%]     Temp ⋯
#      │ Float64   Float64  String     Float64  Vector{Float64}  Float64    Int6 ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 26.528    37.1747  260126-1      2.69  [0.11, 1.0]      0.433918        ⋯
#    2 │  5.59948  39.6825  260126-2      2.52  [0.1, 1.0]       0.259061
#    3 │  4.29725  51.5464  260126-3      1.94  [0.5, 1.0]       0.108925
#    4 │  2.48575  55.8659  260126-4      1.79  [0.5, 1.0]       0.174795
#    5 │  1.99845  54.9451  260126-5      1.82  [0.5, 1.0]       0.27083         ⋯
#    6 │  5.79402  53.4759  260126-6      1.87  [0.5, 1.0]       0.582814
#    7 │  4.7615   34.4828  260126-7      2.32  [0.2, 0.8]       0.0955177
#    8 │  9.09536  31.1284  260126-8      2.57  [0.2, 0.8]       0.111459
#    9 │  2.65678  50.5051  260126-9      1.98  [0.5, 1.0]       0.133137        ⋯
#   10 │  2.46872  50.0     260126-10     2.0   [0.5, 1.0]       0.128125
#   11 │  6.63639  50.0     260126-11     2.0   [0.5, 1.0]       0.488149
#                                                                5 columns omitted

# %% [markdown]
# ## Temperatur 80

# %%
BaseName="AP5ZMEF01-2/260126-"
name="260126-"
file_path = "$(BaseName)$(2).csv"
# Out:
# "AP5ZMEF01-2/260126-2.csv"

# %%
df_260126=[]
# Out:
# Any[]

# %%
aktuellProperties=[]
# Out:
# Any[]

# %%
#### T80


# Plot the first curve with lines and markers
figRaum = Figure(resolution = (1000, 600))
font=24
ax1_Raum = Axis(figRaum[1,1],
    xlabel = L"Weg (mm)",
    ylabel = L"\sigma (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)

ax2_Raum = Axis(figRaum[1,2],
    xlabel = L"\epsilon (%)",
    ylabel = L"\sigma (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)

ax3_Raum = Axis(figRaum[1,3],
    xlabel = L"t (s)",
    ylabel = L"ϵ (%)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)


## Filter Data


for i in [  13 14]
        
        df=TIRA.computeStressStrain(BaseName,name,i,22,As)
        df=TIRA.filter_range(df,"Weg",0,5)
       

        Makie.scatter!(ax1_Raum ,df[!,:Weg],df[!,:Stress];
        markersize=14, 
        label = "T60 $(name)$(i)")


        Makie.scatter!(ax2_Raum ,df[!,:Strain],df[!,:Stress];
        markersize=14, 
        label = "T60 $(name)$(i)")
        limits!(ax2_Raum, 0, 4, 0, 70)

    
        Makie.lines!(ax3_Raum ,df[!,:Zeit],df[!,:Strain];
        
        label = "strain rate $(name)$(i)")
        limits!(ax3_Raum, 0, 500, 0, 5)
        #limits!(ax3_Raum, 0.1, 1,0,30)
        
end

df_DataProperties=DataFrame(DataProperties)

axislegend(ax1_Raum, labelsize=font-10, framevisible=false,position = :rb)
axislegend(ax2_Raum, labelsize=font-10, framevisible=false,position = :rb)
axislegend(ax3_Raum, labelsize=font-10, framevisible=false,position = :rb)
figRaum

# %%
ϵ_LinearRange=[0.5 1]
ϵ_range=[0 2]
t_range=[0 1000] #in order to avoid wrong measurements from the camera
σ_range=[0 35]
T=80
aktuellProperties=[]
# Out:
# Any[]

# %%
#### Raum T
# Plot the first curve with lines and markers
figRaum = Figure(resolution = (1000, 600))
font=24
ax1_Raum = Axis(figRaum[1,1],
    xlabel = L"\epsilon (%)",
    ylabel = L"\sigma (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)

ax2_Raum = Axis(figRaum[1,2],
    xlabel = L"\epsilon (%)",
    ylabel = L"\sigma (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)



for i in [ 13 14]
        
        df=TIRA.computeStressStrain(BaseName,name,i,T,As)
        df=TIRA.filter_range(df,"Zeit",t_range[1],t_range[2])
        df=TIRA.filter_range(df,"dL_ORG",ϵ_range[1],ϵ_range[2])

        properties, df_fit=TIRA.computeProperties(df,ϵ_LinearRange,σ_range)
        
        df_Properties=DataFrame(properties)

        Makie.scatter!(ax1_Raum ,df[!,:Strain],df[!,:Stress];
        markersize=14, 
        label = "T$(T), v=$(round(df_Properties[1," Strain Rate[%/min]"], digits=3)) %/min")
        
        limits!(ax1_Raum, ϵ_range[1],ϵ_range[2], σ_range[1],σ_range[2])


        Makie.scatter!(ax2_Raum ,df[!,:Strain],df[!,:Stress];
        markersize=14, 
        label = "T$(T), v=$(round(df_Properties[1," Strain Rate[%/min]"], digits=3)) %/min")

        Makie.lines!(ax2_Raum ,df_fit[!,:Strain],df_fit[!,:StressFit];
        color = :black, 
        label = "Fit")
        limits!(ax2_Raum, ϵ_LinearRange[1], ϵ_LinearRange[2], σ_range[1],σ_range[2])

        push!(aktuellProperties,properties)
        
end

df_aktuellProperties=DataFrame(aktuellProperties)

axislegend(ax1_Raum, labelsize=font-10, framevisible=false,position = :rb)
axislegend(ax2_Raum, labelsize=font-10, framevisible=false,position = :rb)

figRaum

# %%
df_aktuellProperties
# Out:
# 2×11 DataFrame
#  Row │ e_max[%]  δ_F/δ_B  Probe      δ_B      LinearRange [%]  u_E[%]    Tempe ⋯
#      │ Float64   Float64  String     Float64  Vector{Float64}  Float64   Int64 ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │  3.53694  50.5051  260126-13     1.98  [0.5, 1.0]       0.301246        ⋯
#    2 │  1.62015  51.5464  260126-14     1.94  [0.5, 1.0]       1.15313
#                                                                5 columns omitted

# %%
push!(DataProperties,aktuellProperties[1])
push!(DataProperties,aktuellProperties[2])
# Out:
# 13-element Vector{Any}:
#  Dict{String, Any}("e_max[%]" => 26.527986989324255, "δ_F/δ_B" => 37.17472118959108, "Probe" => "260126-1", "δ_B" => 2.69, "LinearRange [%]" => [0.11, 1.0], "u_E[%] " => 0.43391837312932485, "Temperature [C]" => 22, "E[GPa] " => 3.5792303678701494, "sigmaMax" => 59.677419354838705, "sigma0_25% " => 29.225806451612904…)
#  Dict{String, Any}("e_max[%]" => 5.599483284541063, "δ_F/δ_B" => 39.682539682539684, "Probe" => "260126-2", "δ_B" => 2.52, "LinearRange [%]" => [0.1, 1.0], "u_E[%] " => 0.2590609396773203, "Temperature [C]" => 22, "E[GPa] " => 3.4017543510437074, "sigmaMax" => 63.29032258064516, "sigma0_25% " => 37.16129032258065…)
#  Dict{String, Any}("e_max[%]" => 4.297253383741574, "δ_F/δ_B" => 51.54639175257732, "Probe" => "260126-3", "δ_B" => 1.94, "LinearRange [%]" => [0.5, 1.0], "u_E[%] " => 0.10892456007959146, "Temperature [C]" => 40, "E[GPa] " => 2.5055038139178634, "sigmaMax" => 33.225806451612904, "sigma0_25% " => 20.516129032258064…)
#  Dict{String, Any}("e_max[%]" => 2.4857474006002236, "δ_F/δ_B" => 55.865921787709496, "Probe" => "260126-4", "δ_B" => 1.79, "LinearRange [%]" => [0.5, 1.0], "u_E[%] " => 0.17479501590924829, "Temperature [C]" => 40, "E[GPa] " => 3.0429662077211335, "sigmaMax" => 38.12903225806452, "sigma0_25% " => 30.96774193548387…)
#  Dict{String, Any}("e_max[%]" => 1.998452703357493, "δ_F/δ_B" => 54.94505494505494, "Probe" => "260126-5", "δ_B" => 1.82, "LinearRange [%]" => [0.5, 1.0], "u_E[%] " => 0.2708295533851108, "Temperature [C]" => 40, "E[GPa] " => 2.7190772665381147, "sigmaMax" => 43.29032258064516, "sigma0_25% " => 31.612903225806456…)
#  Dict{String, Any}("e_max[%]" => 5.794019154106645, "δ_F/δ_B" => 53.475935828877, "Probe" => "260126-6", "δ_B" => 1.87, "LinearRange [%]" => [0.5, 1.0], "u_E[%] " => 0.582814461026427, "Temperature [C]" => 40, "E[GPa] " => 2.793102883328682, "sigmaMax" => 42.12903225806452, "sigma0_25% " => 31.548387096774192…)
#  Dict{String, Any}("e_max[%]" => 4.7614998549699274, "δ_F/δ_B" => 34.48275862068966, "Probe" => "260126-7", "δ_B" => 2.32, "LinearRange [%]" => [0.2, 0.8], "u_E[%] " => 0.09551772445256607, "Temperature [C]" => 50, "E[GPa] " => 2.019768517944045, "sigmaMax" => 27.548387096774192, "sigma0_25% " => 17.67741935483871…)
#  Dict{String, Any}("e_max[%]" => 9.095361152674457, "δ_F/δ_B" => 31.128404669260703, "Probe" => "260126-8", "δ_B" => 2.57, "LinearRange [%]" => [0.2, 0.8], "u_E[%] " => 0.1114587717447636, "Temperature [C]" => 50, "E[GPa] " => 1.9333025088918983, "sigmaMax" => 29.03225806451613, "sigma0_25% " => 16.64516129032258…)
#  Dict{String, Any}("e_max[%]" => 2.6567775877604842, "δ_F/δ_B" => 50.505050505050505, "Probe" => "260126-9", "δ_B" => 1.98, "LinearRange [%]" => [0.5, 1.0], "u_E[%] " => 0.1331371876539384, "Temperature [C]" => 60, "E[GPa] " => 1.5230441378320652, "sigmaMax" => 24.516129032258064, "sigma0_25% " => 18.96774193548387…)
#  Dict{String, Any}("e_max[%]" => 2.468715840554638, "δ_F/δ_B" => 50.0, "Probe" => "260126-10", "δ_B" => 2.0, "LinearRange [%]" => [0.5, 1.0], "u_E[%] " => 0.12812461101648345, "Temperature [C]" => 60, "E[GPa] " => 1.6780013391869322, "sigmaMax" => 24.580645161290324, "sigma0_25% " => 16.387096774193548…)
#  Dict{String, Any}("e_max[%]" => 6.636394304366348, "δ_F/δ_B" => 50.0, "Probe" => "260126-11", "δ_B" => 2.0, "LinearRange [%]" => [0.5, 1.0], "u_E[%] " => 0.4881491722876224, "Temperature [C]" => 60, "E[GPa] " => 2.059360720934584, "sigmaMax" => 29.548387096774196, "sigma0_25% " => 16.64516129032258…)
#  Dict{String, Any}("e_max[%]" => 3.53693975477274, "δ_F/δ_B" => 50.505050505050505, "Probe" => "260126-13", "δ_B" => 1.98, "LinearRange [%]" => [0.5, 1.0], "u_E[%] " => 0.3012455693254565, "Temperature [C]" => 80, "E[GPa] " => 1.2804409897048072, "sigmaMax" => 23.032258064516128, "sigma0_25% " => 15.935483870967742…)
#  Dict{String, Any}("e_max[%]" => 1.6201544045700522, "δ_F/δ_B" => 51.54639175257732, "Probe" => "260126-14", "δ_B" => 1.94, "LinearRange [%]" => [0.5, 1.0], "u_E[%] " => 1.1531287998323858, "Temperature [C]" => 80, "E[GPa] " => 1.2680425947140113, "sigmaMax" => 29.419354838709676, "sigma0_25% " => 22.96774193548387…)

# %%
df_DataProperties=DataFrame(DataProperties)
# Out:
# 13×11 DataFrame
#  Row │ e_max[%]  δ_F/δ_B  Probe      δ_B      LinearRange [%]  u_E[%]     Temp ⋯
#      │ Float64   Float64  String     Float64  Vector{Float64}  Float64    Int6 ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 26.528    37.1747  260126-1      2.69  [0.11, 1.0]      0.433918        ⋯
#    2 │  5.59948  39.6825  260126-2      2.52  [0.1, 1.0]       0.259061
#    3 │  4.29725  51.5464  260126-3      1.94  [0.5, 1.0]       0.108925
#    4 │  2.48575  55.8659  260126-4      1.79  [0.5, 1.0]       0.174795
#    5 │  1.99845  54.9451  260126-5      1.82  [0.5, 1.0]       0.27083         ⋯
#    6 │  5.79402  53.4759  260126-6      1.87  [0.5, 1.0]       0.582814
#    7 │  4.7615   34.4828  260126-7      2.32  [0.2, 0.8]       0.0955177
#    8 │  9.09536  31.1284  260126-8      2.57  [0.2, 0.8]       0.111459
#    9 │  2.65678  50.5051  260126-9      1.98  [0.5, 1.0]       0.133137        ⋯
#   10 │  2.46872  50.0     260126-10     2.0   [0.5, 1.0]       0.128125
#   11 │  6.63639  50.0     260126-11     2.0   [0.5, 1.0]       0.488149
#   12 │  3.53694  50.5051  260126-13     1.98  [0.5, 1.0]       0.301246
#   13 │  1.62015  51.5464  260126-14     1.94  [0.5, 1.0]       1.15313         ⋯
#                                                                5 columns omitted

# %% [markdown]
# ## Temperatur 100

# %%
BaseName="AP5ZMEF01-2/260126-"
name="260126-"
file_path = "$(BaseName)$(2).csv"
# Out:
# "AP5ZMEF01-2/260126-2.csv"

# %%
df_260126=[]
# Out:
# Any[]

# %%
aktuellProperties=[]
# Out:
# Any[]

# %%
#### T100


# Plot the first curve with lines and markers
figRaum = Figure(resolution = (1000, 600))
font=24
ax1_Raum = Axis(figRaum[1,1],
    xlabel = L"Weg (mm)",
    ylabel = L"\sigma (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)

ax2_Raum = Axis(figRaum[1,2],
    xlabel = L"\epsilon (%)",
    ylabel = L"\sigma (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)

ax3_Raum = Axis(figRaum[1,3],
    xlabel = L"t (s)",
    ylabel = L"ϵ (%)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)


## Filter Data


for i in [  15 16]
        
        df=TIRA.computeStressStrain(BaseName,name,i,22,As)
        df=TIRA.filter_range(df,"Weg",0,5)
       

        Makie.scatter!(ax1_Raum ,df[!,:Weg],df[!,:Stress];
        markersize=14, 
        label = "T100 $(name)$(i)")


        Makie.scatter!(ax2_Raum ,df[!,:Strain],df[!,:Stress];
        markersize=14, 
        label = "T100 $(name)$(i)")
        limits!(ax2_Raum, 0, 4, 0, 70)

    
        Makie.lines!(ax3_Raum ,df[!,:Zeit],df[!,:Strain];
        
        label = "strain rate $(name)$(i)")
        limits!(ax3_Raum, 0, 500, 0, 5)
        #limits!(ax3_Raum, 0.1, 1,0,30)
        
end

df_DataProperties=DataFrame(DataProperties)

axislegend(ax1_Raum, labelsize=font-10, framevisible=false,position = :rb)
axislegend(ax2_Raum, labelsize=font-10, framevisible=false,position = :rb)
axislegend(ax3_Raum, labelsize=font-10, framevisible=false,position = :rb)
figRaum

# %%
ϵ_LinearRange=[0.5 1]
ϵ_range=[0 2]
t_range=[0 1000] #in order to avoid wrong measurements from the camera
σ_range=[0 35]
T=100
aktuellProperties=[]
# Out:
# Any[]

# %%
#### Raum T
# Plot the first curve with lines and markers
figRaum = Figure(resolution = (1000, 600))
font=24
ax1_Raum = Axis(figRaum[1,1],
    xlabel = L"\epsilon (%)",
    ylabel = L"\sigma (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)

ax2_Raum = Axis(figRaum[1,2],
    xlabel = L"\epsilon (%)",
    ylabel = L"\sigma (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)



for i in [ 13 14]
        
        df=TIRA.computeStressStrain(BaseName,name,i,T,As)
        df=TIRA.filter_range(df,"Zeit",t_range[1],t_range[2])
        df=TIRA.filter_range(df,"dL_ORG",ϵ_range[1],ϵ_range[2])

        properties, df_fit=TIRA.computeProperties(df,ϵ_LinearRange,σ_range)
        
        df_Properties=DataFrame(properties)

        Makie.scatter!(ax1_Raum ,df[!,:Strain],df[!,:Stress];
        markersize=14, 
        label = "T$(T), v=$(round(df_Properties[1," Strain Rate[%/min]"], digits=3)) %/min")
        
        limits!(ax1_Raum, ϵ_range[1],ϵ_range[2], σ_range[1],σ_range[2])


        Makie.scatter!(ax2_Raum ,df[!,:Strain],df[!,:Stress];
        markersize=14, 
        label = "T$(T), v=$(round(df_Properties[1," Strain Rate[%/min]"], digits=3)) %/min")

        Makie.lines!(ax2_Raum ,df_fit[!,:Strain],df_fit[!,:StressFit];
        color = :black, 
        label = "Fit")
        limits!(ax2_Raum, ϵ_LinearRange[1], ϵ_LinearRange[2], σ_range[1],σ_range[2])

        push!(aktuellProperties,properties)
        
end

df_aktuellProperties=DataFrame(aktuellProperties)

axislegend(ax1_Raum, labelsize=font-10, framevisible=false,position = :rb)
axislegend(ax2_Raum, labelsize=font-10, framevisible=false,position = :rb)

figRaum

# %%
df_aktuellProperties
# Out:
# 2×11 DataFrame
#  Row │ e_max[%]  δ_F/δ_B  Probe      δ_B      LinearRange [%]  u_E[%]    Tempe ⋯
#      │ Float64   Float64  String     Float64  Vector{Float64}  Float64   Int64 ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │  3.53694  50.5051  260126-13     1.98  [0.5, 1.0]       0.301246        ⋯
#    2 │  1.62015  51.5464  260126-14     1.94  [0.5, 1.0]       1.15313
#                                                                5 columns omitted

# %%
push!(DataProperties,aktuellProperties[1])
push!(DataProperties,aktuellProperties[2])
# Out:
# 15-element Vector{Any}:
#  Dict{String, Any}("e_max[%]" => 26.527986989324255, "δ_F/δ_B" => 37.17472118959108, "Probe" => "260126-1", "δ_B" => 2.69, "LinearRange [%]" => [0.11, 1.0], "u_E[%] " => 0.43391837312932485, "Temperature [C]" => 22, "E[GPa] " => 3.5792303678701494, "sigmaMax" => 59.677419354838705, "sigma0_25% " => 29.225806451612904…)
#  Dict{String, Any}("e_max[%]" => 5.599483284541063, "δ_F/δ_B" => 39.682539682539684, "Probe" => "260126-2", "δ_B" => 2.52, "LinearRange [%]" => [0.1, 1.0], "u_E[%] " => 0.2590609396773203, "Temperature [C]" => 22, "E[GPa] " => 3.4017543510437074, "sigmaMax" => 63.29032258064516, "sigma0_25% " => 37.16129032258065…)
#  Dict{String, Any}("e_max[%]" => 4.297253383741574, "δ_F/δ_B" => 51.54639175257732, "Probe" => "260126-3", "δ_B" => 1.94, "LinearRange [%]" => [0.5, 1.0], "u_E[%] " => 0.10892456007959146, "Temperature [C]" => 40, "E[GPa] " => 2.5055038139178634, "sigmaMax" => 33.225806451612904, "sigma0_25% " => 20.516129032258064…)
#  Dict{String, Any}("e_max[%]" => 2.4857474006002236, "δ_F/δ_B" => 55.865921787709496, "Probe" => "260126-4", "δ_B" => 1.79, "LinearRange [%]" => [0.5, 1.0], "u_E[%] " => 0.17479501590924829, "Temperature [C]" => 40, "E[GPa] " => 3.0429662077211335, "sigmaMax" => 38.12903225806452, "sigma0_25% " => 30.96774193548387…)
#  Dict{String, Any}("e_max[%]" => 1.998452703357493, "δ_F/δ_B" => 54.94505494505494, "Probe" => "260126-5", "δ_B" => 1.82, "LinearRange [%]" => [0.5, 1.0], "u_E[%] " => 0.2708295533851108, "Temperature [C]" => 40, "E[GPa] " => 2.7190772665381147, "sigmaMax" => 43.29032258064516, "sigma0_25% " => 31.612903225806456…)
#  Dict{String, Any}("e_max[%]" => 5.794019154106645, "δ_F/δ_B" => 53.475935828877, "Probe" => "260126-6", "δ_B" => 1.87, "LinearRange [%]" => [0.5, 1.0], "u_E[%] " => 0.582814461026427, "Temperature [C]" => 40, "E[GPa] " => 2.793102883328682, "sigmaMax" => 42.12903225806452, "sigma0_25% " => 31.548387096774192…)
#  Dict{String, Any}("e_max[%]" => 4.7614998549699274, "δ_F/δ_B" => 34.48275862068966, "Probe" => "260126-7", "δ_B" => 2.32, "LinearRange [%]" => [0.2, 0.8], "u_E[%] " => 0.09551772445256607, "Temperature [C]" => 50, "E[GPa] " => 2.019768517944045, "sigmaMax" => 27.548387096774192, "sigma0_25% " => 17.67741935483871…)
#  Dict{String, Any}("e_max[%]" => 9.095361152674457, "δ_F/δ_B" => 31.128404669260703, "Probe" => "260126-8", "δ_B" => 2.57, "LinearRange [%]" => [0.2, 0.8], "u_E[%] " => 0.1114587717447636, "Temperature [C]" => 50, "E[GPa] " => 1.9333025088918983, "sigmaMax" => 29.03225806451613, "sigma0_25% " => 16.64516129032258…)
#  Dict{String, Any}("e_max[%]" => 2.6567775877604842, "δ_F/δ_B" => 50.505050505050505, "Probe" => "260126-9", "δ_B" => 1.98, "LinearRange [%]" => [0.5, 1.0], "u_E[%] " => 0.1331371876539384, "Temperature [C]" => 60, "E[GPa] " => 1.5230441378320652, "sigmaMax" => 24.516129032258064, "sigma0_25% " => 18.96774193548387…)
#  Dict{String, Any}("e_max[%]" => 2.468715840554638, "δ_F/δ_B" => 50.0, "Probe" => "260126-10", "δ_B" => 2.0, "LinearRange [%]" => [0.5, 1.0], "u_E[%] " => 0.12812461101648345, "Temperature [C]" => 60, "E[GPa] " => 1.6780013391869322, "sigmaMax" => 24.580645161290324, "sigma0_25% " => 16.387096774193548…)
#  Dict{String, Any}("e_max[%]" => 6.636394304366348, "δ_F/δ_B" => 50.0, "Probe" => "260126-11", "δ_B" => 2.0, "LinearRange [%]" => [0.5, 1.0], "u_E[%] " => 0.4881491722876224, "Temperature [C]" => 60, "E[GPa] " => 2.059360720934584, "sigmaMax" => 29.548387096774196, "sigma0_25% " => 16.64516129032258…)
#  Dict{String, Any}("e_max[%]" => 3.53693975477274, "δ_F/δ_B" => 50.505050505050505, "Probe" => "260126-13", "δ_B" => 1.98, "LinearRange [%]" => [0.5, 1.0], "u_E[%] " => 0.3012455693254565, "Temperature [C]" => 80, "E[GPa] " => 1.2804409897048072, "sigmaMax" => 23.032258064516128, "sigma0_25% " => 15.935483870967742…)
#  Dict{String, Any}("e_max[%]" => 1.6201544045700522, "δ_F/δ_B" => 51.54639175257732, "Probe" => "260126-14", "δ_B" => 1.94, "LinearRange [%]" => [0.5, 1.0], "u_E[%] " => 1.1531287998323858, "Temperature [C]" => 80, "E[GPa] " => 1.2680425947140113, "sigmaMax" => 29.419354838709676, "sigma0_25% " => 22.96774193548387…)
#  Dict{String, Any}("e_max[%]" => 3.53693975477274, "δ_F/δ_B" => 50.505050505050505, "Probe" => "260126-13", "δ_B" => 1.98, "LinearRange [%]" => [0.5, 1.0], "u_E[%] " => 0.3012455693254565, "Temperature [C]" => 100, "E[GPa] " => 1.2804409897048072, "sigmaMax" => 23.032258064516128, "sigma0_25% " => 15.935483870967742…)
#  Dict{String, Any}("e_max[%]" => 1.6201544045700522, "δ_F/δ_B" => 51.54639175257732, "Probe" => "260126-14", "δ_B" => 1.94, "LinearRange [%]" => [0.5, 1.0], "u_E[%] " => 1.1531287998323858, "Temperature [C]" => 100, "E[GPa] " => 1.2680425947140113, "sigmaMax" => 29.419354838709676, "sigma0_25% " => 22.96774193548387…)

# %%
df_DataProperties=DataFrame(DataProperties)
# Out:
# 15×11 DataFrame
#  Row │ e_max[%]  δ_F/δ_B  Probe      δ_B      LinearRange [%]  u_E[%]     Temp ⋯
#      │ Float64   Float64  String     Float64  Vector{Float64}  Float64    Int6 ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 26.528    37.1747  260126-1      2.69  [0.11, 1.0]      0.433918        ⋯
#    2 │  5.59948  39.6825  260126-2      2.52  [0.1, 1.0]       0.259061
#    3 │  4.29725  51.5464  260126-3      1.94  [0.5, 1.0]       0.108925
#    4 │  2.48575  55.8659  260126-4      1.79  [0.5, 1.0]       0.174795
#    5 │  1.99845  54.9451  260126-5      1.82  [0.5, 1.0]       0.27083         ⋯
#    6 │  5.79402  53.4759  260126-6      1.87  [0.5, 1.0]       0.582814
#    7 │  4.7615   34.4828  260126-7      2.32  [0.2, 0.8]       0.0955177
#    8 │  9.09536  31.1284  260126-8      2.57  [0.2, 0.8]       0.111459
#    9 │  2.65678  50.5051  260126-9      1.98  [0.5, 1.0]       0.133137        ⋯
#   10 │  2.46872  50.0     260126-10     2.0   [0.5, 1.0]       0.128125
#   11 │  6.63639  50.0     260126-11     2.0   [0.5, 1.0]       0.488149
#   12 │  3.53694  50.5051  260126-13     1.98  [0.5, 1.0]       0.301246
#   13 │  1.62015  51.5464  260126-14     1.94  [0.5, 1.0]       1.15313         ⋯
#   14 │  3.53694  50.5051  260126-13     1.98  [0.5, 1.0]       0.301246
#   15 │  1.62015  51.5464  260126-14     1.94  [0.5, 1.0]       1.15313
#                                                                5 columns omitted
