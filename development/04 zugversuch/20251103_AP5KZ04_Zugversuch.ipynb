# %%
using Pkg
using CSV
using DataFrames
using Polynomials
using CairoMakie
using Statistics

# %% [markdown]
# ## Plots

# %% [markdown]
# ### fig1

# %%
using Plots

# Plot the first curve with lines and markers
fig = Figure(resolution = (1200, 1200))
font=24
ax1 = Axis(fig[1,1],
    xlabel = L"\epsilon (%)",
    ylabel = L"\sigma (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)


ax2 = Axis(fig[1,2],
    xlabel = L"\epsilon (%)",
    ylabel = L"\sigma (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)


ax3 = Axis(fig[2,1],
    xlabel = L"v (%/min)",
    ylabel = L"E (GPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)

ax4 = Axis(fig[2,2],
    xlabel = L"v (%/min)",
    ylabel = L"\sigma_B (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)

ax5 = Axis(fig[2,3],
    xlabel = L"v (%/min)",
    ylabel = L"\sigma_F (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)
# Out:
# Axis with 0 plots:

# %% [markdown]
# ### Fig2

# %%
fig2 = Figure(resolution = (1200, 1200))
font=24
ax1_2 = Axis(fig2[1,1],
    xlabel = L"\epsilon (%)",
    ylabel = L"\sigma (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)


ax2_2 = Axis(fig2[1,2],
    xlabel = L"\epsilon (%)",
    ylabel = L"\sigma (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)


ax3_2 = Axis(fig2[2,1],
    xlabel = L"v (%/min)",
    ylabel = L"E (GPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)

ax4_2 = Axis(fig2[2,2],
    xlabel = L"v (%/min)",
    ylabel = L"\sigma_B (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)

ax5_2 = Axis(fig2[2,3],
    xlabel = L"v (%/min)",
    ylabel = L"\sigma_F (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)
# Out:
# Axis with 0 plots:

# %% [markdown]
# ### Fig3

# %%
fig3 = Figure(resolution = (1200, 1200))
font=24
ax1_3 = Axis(fig3[1,1],
    xlabel = L"\epsilon (%)",
    ylabel = L"\sigma (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)


ax2_3 = Axis(fig3[1,2],
    xlabel = L"\epsilon (%)",
    ylabel = L"\sigma (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)


ax3_3 = Axis(fig3[2,1],
    xlabel = L"v (%/min)",
    ylabel = L"E (GPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)

ax4_3 = Axis(fig3[2,2],
    xlabel = L"v (%/min)",
    ylabel = L"\sigma_B (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)

ax5_3 = Axis(fig3[2,3],
    xlabel = L"v (%/min)",
    ylabel = L"\sigma_F (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)
# Out:
# Axis with 0 plots:

# %% [markdown]
# ### Fig4

# %%
fig4 = Figure(resolution = (1200, 600))
font=24
ax1_4 = Axis(fig4[1,1],
    xlabel = L"\epsilon (%)",
    ylabel = L"\sigma (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)


ax2_4 = Axis(fig4[1,2],
    xlabel = L"\epsilon (%)",
    ylabel = L"\sigma (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)
# Out:
# Axis with 0 plots:

# %% [markdown]
# ## Functions

# %%
function import_TIRA(file_path)
    
    df=CSV.read(file_path,DataFrame) 
    df.Zeit = parse.(Float64, replace.(df.Zeit, "," => "."))
    df.Länge = parse.(Float64, replace.(df.Länge, "," => "."))
    df.Weg = parse.(Float64, replace.(df.Weg, "," => "."))
    #df.Dehnung = parse.(Float64, replace.(df.Dehnung, "," => "."))
    df.Kraft = parse.(Float64, replace.(df.Kraft, "," => "."))
    df.dL_ORG = parse.(Float64, replace.(df.dL_ORG, "," => "."))

    return df

end

function filter_range(df::DataFrame, column::String, low, high)
    return filter(row -> low ≤ row[column] ≤ high, df)
end
# Out:
# filter_range (generic function with 1 method)

# %%
function get_corresponding(df::DataFrame, search_col::Symbol, search_val, return_col::Symbol)
    row = findfirst(df[!, search_col] .== search_val)
    return row === nothing ? missing : df[row, return_col]
end
# Out:
# get_corresponding (generic function with 1 method)

# %%
function u_E(X,Y)
    p_fit=fit(X,Y,1)
    y_fit = p_fit.(X)
    residuals = y_fit - Y   # residuals
    
    σ_res = std(residuals, corrected=true) 
    X_mean = mean(X)
    stderr_slope = σ_res / sqrt(sum((X .- X_mean).^2))


    return stderr_slope
end
# Out:
# u_E (generic function with 1 method)

# %%
function getMechanicalProperties(fig,ax1,ax2,log_total,df_Group,LinearRange,StressRange,Temperature)

        log=[]
        for i in df_Group
            
            T=i[!,:Zeit]
            X=i[!,:dL_ORG]
            Y=i[!,:Stress]
            df_linear=filter_range(i,"Stress",StressRange[1],StressRange[2])
            df_linear=filter_range(df_linear,"dL_ORG",LinearRange[1],LinearRange[2])
            T_linear=df_linear[!,:Zeit]
            X_linear=df_linear[!,:dL_ORG]
            Y_linear=df_linear[!,:Stress]

            sigma0_25=maximum(Y_linear)
            sigmaB=maximum(Y)
            sigmaF=maximum(Y_linear)
            # Fit a 1st-degree polynomial (linear)
            fit_X_T=fit(T_linear,X_linear*60,1)
            
            strainRate=fit_X_T[1]
            
            # Fit a 1st-degree polynomial (linear)
            p_fit=fit(X_linear/100,Y_linear,1)
            E_modul=p_fit[1]/1000
            u_EModul=u_E(X_linear/100,Y_linear/1000)


            Makie.scatter!(ax1,X,Y; markersize=12, label = "$(round(strainRate, digits=3)) [%/min]") 
            #Makie.scatter!(ax1,X,Y; markersize=12,)
            Makie.scatter!(ax2,X_linear,Y_linear; markersize=12, label = "$(round(strainRate, digits=3)) [%/min]")
            
            δ_B=get_corresponding(i,:Stress,maximum(i[!,:Stress]),:dL_ORG)
            sum=Dict("Probe"=>i[1,:Name],
                    " Strain Rate[%/min]"=>strainRate,
                    "E[GPa] "=>E_modul,
                    "u_E[GPa] "=>u_EModul,
                    "sigma0_25% "=> sigma0_25,
                    "sigmaMax"=> sigmaB,
                    "δ_B"=> δ_B,
                    "δ_F/δ_B"=>df_linear[end,:dL_ORG]*100/δ_B,
                    "Temperature [C]"=> Temperature,
                    "LinearRange [%]"=>[df_linear[1,:dL_ORG],df_linear[end,:dL_ORG]])
            push!(log,sum)
            push!(log_total,sum)
            


        end

        axislegend(ax1, labelsize=font-10, framevisible=false)
        axislegend(ax2, labelsize=font-10, framevisible=false)

        df_log=DataFrame(log)
        return df_log,log_total,fig

end
# Out:
# getMechanicalProperties (generic function with 1 method)

# %%
function plotVariableTemperature!(fig,ax1,ax2,df,LinearRange,StressRange,Temperature)

        log=[]
        
            
            T=df[!,:Zeit]
            X=df[!,:dL_ORG]
            Y=df[!,:Stress]
            df_linear=filter_range(df,"Stress",StressRange[1],StressRange[2])
            df_linear=filter_range(df_linear,"dL_ORG",LinearRange[1],LinearRange[2])
            T_linear=df_linear[!,:Zeit]
            X_linear=df_linear[!,:dL_ORG]
            Y_linear=df_linear[!,:Stress]

            # Fit a 1st-degree polynomial (linear)
            fit_X_T=fit(T_linear,X_linear*60,1)
            
            strainRate=fit_X_T[1]


            Makie.scatter!(ax1,X,Y; markersize=12, label = "T=$Temperature C v=$(round(strainRate, digits=3)) [%/min]")
            
            Makie.scatter!(ax2,X_linear,Y_linear; markersize=12, label = "T=$Temperature C v=$(round(strainRate, digits=3)) [%/min]")

           
   
        return fig

end
# Out:
# plotVariableTemperature! (generic function with 1 method)

# %%
function plotProperties!(fig, df_log,ax1,ax2,ax3)
        

        epsilon=df_log[!," Strain Rate[%/min]"]
        E=df_log[!,"E[GPa] "]
        Makie.scatter!(ax1,epsilon,E)
        Makie.lines!(ax1,epsilon,E)

        Makie.scatter!(ax2,df_log[!," Strain Rate[%/min]"],df_log[!,"sigmaMax"])
        Makie.lines!(ax2,df_log[!," Strain Rate[%/min]"],df_log[!,"sigmaMax"])


        Makie.scatter!(ax3,df_log[!," Strain Rate[%/min]"],df_log[!,"sigma0_25% "])
        Makie.lines!(ax3,df_log[!," Strain Rate[%/min]"],df_log[!,"sigma0_25% "])
        
        
        return fig

end
# Out:
# plotProperties! (generic function with 1 method)

# %% [markdown]
# ## Proben Geometrie

# %%
## Geometrie
w=10*1e-3 # Width
t=15*1e-6 # thickness
l=75*1e-3 # length
As=w*t    # stress section
# Out:
# 1.5e-7

# %% [markdown]
# ## Raum Temperatur

# %%
log_total=[]
# Out:
# Any[]

# %%
#### Probe 1

    # Replace with the ath to your Excel file


    #file_path="AP5ZK03/251006-01.csv"
    #df=import_TIRA(file_path)
    #df[!,:Name]=fill("251006-01", nrow(df))
    #df[!,:Stress]=df[!,:Kraft]*1e-6/As
    #df[!,:Strain]=df[!,:dL_ORG]/100
    #df_filtered=filter_range(df,"dL_ORG",0,5)
    #T=df_filtered[!,:Zeit]
    #X=df_filtered[!,:dL_ORG]
    #Y=df_filtered[!,:Kraft]

    #df_Group=[]
    #push!(df_Group,df_filtered)

    #df_log,log_total,fig=getMechanicalProperties(fig,ax1,ax2,log_total,df_Group,[0.1 0.25],[0 20],22)

    #fig=plotProperties!(fig, df_log,ax3,ax4,ax5)
    #fig

# %%
#### Raum T

    BaseName="AP5ZK04/251103-"
    name="251103-"
    df_Group=[]
    df_Group_Total=[]
    for i in [1,2]
        file_path = "$(BaseName)$(i).csv"
        df=import_TIRA(file_path)
        df[!,:Name]=fill("$(name)$(i)", nrow(df))
        df[!,:Stress]=df[!,:Kraft]*1e-6/As
        df[!,:Strain]=df[!,:dL_ORG]/100
        df_filtered=filter_range(df,"dL_ORG",0,3)
        push!(df_Group,df_filtered)
        push!(df_Group_Total,df_filtered)
    end

    df_log,log_total,fig=getMechanicalProperties(fig,ax1,ax2,log_total,df_Group,[0.1 1],[0 100],22)
    fig=plotProperties!(fig, df_log,ax3,ax4,ax5)
    fig

# %% [markdown]
# ## Temperatur 50C

# %%
#### Gesamtgruppe um 50 °C

    BaseName="AP5ZK04/251103-"
    name="251103-0"
    df_Group=[]

   for i in [3,5,6,7]
        file_path = "$(BaseName)$(i).csv"
        df=import_TIRA(file_path)
        df[!,:Name]=fill("$(name)$(i)", nrow(df))
        df[!,:Stress]=df[!,:Kraft]*1e-6/As
        df[!,:Strain]=df[!,:dL_ORG]/100
        df_filtered=filter_range(df,"dL_ORG",0.1,3)
        push!(df_Group,df_filtered)
        push!(df_Group_Total,df_filtered)
    end

    df_log,log_total,fig2=getMechanicalProperties(fig2,ax1_2,ax2_2,log_total,df_Group,[0.1 1],[0 100],50)
    fig2=plotProperties!(fig2, df_log,ax3_2,ax4_2,ax5_2)

    fig2

# %% [markdown]
# ## Temperatur 100C

# %%
#### Gesamtgruppe um 100 °C

    BaseName="AP5ZK04/251103-"
    name="251103-"
    df_Group=[]

   for i in [8,10]
        file_path = "$(BaseName)$(i).csv"
        df=import_TIRA(file_path)
        df[!,:Name]=fill("$(name)$(i)", nrow(df))
        df[!,:Stress]=df[!,:Kraft]*1e-6/As
        s0=df[1,:dL_ORG]
        df[!,:dL_ORG]=(df[!,:dL_ORG].-s0)
        df[!,:Strain]=df[!,:dL_ORG]/100
        df_filtered=filter_range(df,"dL_ORG",0.1,3)
        push!(df_Group,df_filtered)
        push!(df_Group_Total,df_filtered)
    end


    df_log,log_total,fig3=getMechanicalProperties(fig3,ax1_3,ax2_3,log_total,df_Group,[0.8 1.5],[0 100],100)
    fig3=plotProperties!(fig3, df_log,ax3_3,ax4_3,ax5_3)

    fig3

# %% [markdown]
# ## Comparison

# %%
df_Group_Total[1]
# Out:
# 319×8 DataFrame
#  Row │ Zeit     Weg      Kraft    Länge    dL_ORG   Name      Stress     Strai ⋯
#      │ Float64  Float64  Float64  Float64  Float64  String    Float64    Float ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │    0.02     0.05     0.1      0.0      0.0   251103-1   0.666667   0.0  ⋯
#    2 │    0.04     0.05     0.1      0.0      0.0   251103-1   0.666667   0.0
#    3 │    0.06     0.05     0.09     0.0      0.0   251103-1   0.6        0.0
#    4 │    0.08     0.05     0.09     0.0      0.0   251103-1   0.6        0.0
#    5 │    0.1      0.05     0.09     0.0      0.0   251103-1   0.6        0.0  ⋯
#    6 │    0.12     0.05     0.09     0.0      0.0   251103-1   0.6        0.0
#    7 │    0.14     0.05     0.1      0.0      0.0   251103-1   0.666667   0.0
#    8 │    0.16     0.05     0.1      0.0      0.0   251103-1   0.666667   0.0
#   ⋮  │    ⋮        ⋮        ⋮        ⋮        ⋮        ⋮          ⋮         ⋮  ⋱
#  313 │    6.26     1.8      9.91     2.55     2.55  251103-1  66.0667     0.02 ⋯
#  314 │    6.28     1.81     8.35     2.54     2.54  251103-1  55.6667     0.02
#  315 │    6.3      1.81     6.38     2.54     2.54  251103-1  42.5333     0.02
#  316 │    6.32     1.82     4.41     2.54     2.54  251103-1  29.4        0.02
#  317 │    6.34     1.82     2.43     2.54     2.54  251103-1  16.2        0.02 ⋯
#  318 │    6.36     1.83     0.49     2.54     2.54  251103-1   3.26667    0.02
#  319 │    6.38     1.84     0.05     2.54     2.54  251103-1   0.333333   0.02
#                                                    1 column and 304 rows omitted

# %%
df_Group=[]
for i in [7,10, 12]
    push!(df_Group,df_Group_Total[i])
    
end

Temperaturen=[22 50 100]

for i in 1:length(df_Group)

    fig4=plotVariableTemperature!(fig4,ax1_4,ax2_4,df_Group[i],[0.1 0.25],[0 100],Temperaturen[i])

end

axislegend(ax1_4, labelsize=font-10, framevisible=false)
axislegend(ax2_4, labelsize=font-10, framevisible=false)
# Out:
# BoundsError: attempt to access 8-element Vector{Any} at index [10]
#
#
#
# Stacktrace:
#
#  [1] getindex(A::Vector{Any}, i1::Int64)
#
#    @ Base .\essentials.jl:13
#
#  [2] top-level scope
#
#    @ d:\01 Projekt\03 Programm\Rini aktuell\Rini\development\zugversuch\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_Y133sZmlsZQ==.jl:3

# %%
fig4

# %% [markdown]
# ## Ergebnisse

# %%
df_log_total=DataFrame(log_total)
df_log_total
# Out:
# 8×10 DataFrame
#  Row │ δ_F/δ_B  LinearRange [%]  u_E[GPa]   Probe      δ_B      Temperature [C ⋯
#      │ Float64  Vector{Float64}  Float64    String     Float64  Int64          ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 41.841   [0.11, 1.0]      0.0139279  251103-1      2.39               2 ⋯
#    2 │ 39.5257  [0.1, 1.0]       0.0137708  251103-2      2.53               2
#    3 │ 38.5827  [0.1, 0.98]      0.0212613  251103-03     2.54               5
#    4 │ 45.4545  [0.1, 1.0]       0.0160469  251103-05     2.2                5
#    5 │ 45.2489  [0.11, 1.0]      0.0133149  251103-06     2.21               5 ⋯
#    6 │ 43.29    [0.1, 1.0]       0.0142528  251103-07     2.31               5
#    7 │ 60.241   [0.8, 1.5]       0.0158818  251103-8      2.49              10
#    8 │ 54.1516  [0.81, 1.5]      0.0128079  251103-10     2.77              10
#                                                                5 columns omitted

# %%
fig

# %%
fig2

# %%
fig3

# %% [markdown]
# ## Bericht Plots

# %%
fig = Figure(resolution = (1000, 600))
font=36
ax1 = Axis(fig[1,1],
    xlabel = L"\epsilon (%)",
    ylabel = L"\sigma (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)
# Out:
# Axis with 0 plots:

# %%
print(df_Group)

# %%
#### Raum T

    BaseName="AP5ZK03/251103-"
    name="251103-"
    df_Group2=[]
    
    for i in [2,]
        file_path = "$(BaseName)$(i).csv"
        df=import_TIRA(file_path)
        df[!,:Name]=fill("$(name)$(i)", nrow(df))
        df[!,:Stress]=df[!,:Kraft]*1e-6/As
        df[!,:Strain]=df[!,:dL_ORG]/100
        df_filtered=filter_range(df,"dL_ORG",0,3.6)
        push!(df_Group2,df_filtered)
        
    end

    df_log,log_total,fig=getMechanicalProperties(fig,ax1,ax2,log_total,df_Group2,[0.1 0.25],[0 20],22)
    fig=plotProperties!(fig, df_log,ax3,ax4,ax5)
    
   fig
# Out:
# There are no plots with labels in the given axis that can be put in the legend. Supply labels to plotting functions like `plot(args...; label = "My label")`
#
#
#
# Stacktrace:
#
#  [1] error(s::String)
#
#    @ Base .\error.jl:35
#
#  [2] Legend(fig_or_scene::Figure, axis::Axis, title::Nothing; merge::Bool, unique::Bool, kwargs::@Kwargs{bbox::Observable{GeometryBasics.HyperRectangle{2, Int64}}, margin::NTuple{4, Int64}, halign::Symbol, valign::Symbol, labelsize::Int64, framevisible::Bool})
#
#    @ Makie C:\Users\rinc\.julia\packages\Makie\RgxaV\src\makielayout\blocks\legend.jl:552
#
#  [3] Legend
#
#    @ C:\Users\rinc\.julia\packages\Makie\RgxaV\src\makielayout\blocks\legend.jl:550 [inlined]
#
#  [4] #axislegend#2000
#
#    @ C:\Users\rinc\.julia\packages\Makie\RgxaV\src\makielayout\blocks\legend.jl:618 [inlined]
#
#  [5] axislegend
#
#    @ C:\Users\rinc\.julia\packages\Makie\RgxaV\src\makielayout\blocks\legend.jl:617 [inlined]
#
#  [6] #axislegend#1998
#
#    @ C:\Users\rinc\.julia\packages\Makie\RgxaV\src\makielayout\blocks\legend.jl:594 [inlined]
#
#  [7] getMechanicalProperties(fig::Figure, ax1::Axis, ax2::Axis, log_total::Vector{Any}, df_Group::Vector{Any}, LinearRange::Matrix{Float64}, StressRange::Matrix{Int64}, Temperature::Int64)
#
#    @ Main d:\01 Projekt\03 Programm\Rini aktuell\Rini\development\zugversuch\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X20sZmlsZQ==.jl:47
#
#  [8] top-level scope
#
#    @ d:\01 Projekt\03 Programm\Rini aktuell\Rini\development\zugversuch\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X52sZmlsZQ==.jl:18

# %%
 ax1.xticks = LinearTicks(10)   # 20 divisions on X
 ax1.yticks = LinearTicks(10)
 fig
 save("tensile.svg",fig)
# Out:
# CairoMakie.Screen{SVG}

# %%
fig4 = Figure(resolution = (1200, 600))
font=24
ax1_4 = Axis(fig4[1,1],
    xlabel = L"\epsilon (%)",
    ylabel = L"\sigma (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)


ax2_4 = Axis(fig4[1,2],
    xlabel = L"\epsilon (%)",
    ylabel = L"\sigma (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)
# Out:
# Axis with 0 plots:

# %%
df_Group2
# Out:
# 3-element Vector{Any}:
#  9615×8 DataFrame
#   Row │ Zeit     Weg      Kraft    Länge    dL_ORG   Name       Stress     Str ⋯
#       │ Float64  Float64  Float64  Float64  Float64  String     Float64    Flo ⋯
# ──────┼─────────────────────────────────────────────────────────────────────────
#     1 │    0.02     0.03     0.11      0.0      0.0  251006-08   0.733333      ⋯
#     2 │    0.04     0.04     0.11      0.0      0.0  251006-08   0.733333
#     3 │    0.06     0.04     0.11      0.0      0.0  251006-08   0.733333
#     4 │    0.08     0.04     0.11      0.0      0.0  251006-08   0.733333
#     5 │    0.1      0.04     0.11      0.0      0.0  251006-08   0.733333      ⋯
#     6 │    0.12     0.04     0.11      0.0      0.0  251006-08   0.733333
#     7 │    0.14     0.04     0.11      0.0      0.0  251006-08   0.733333
#     8 │    0.16     0.04     0.11      0.0      0.0  251006-08   0.733333
#   ⋮   │    ⋮        ⋮        ⋮        ⋮        ⋮         ⋮          ⋮          ⋱
#  9609 │  192.18     1.64     6.52      3.0      3.0  251006-08  43.4667        ⋯
#  9610 │  192.2      1.64     6.52      3.0      3.0  251006-08  43.4667
#  9611 │  192.22     1.64     6.52      3.0      3.0  251006-08  43.4667
#  9612 │  192.24     1.64     6.52      3.0      3.0  251006-08  43.4667
#  9613 │  192.26     1.64     6.52      3.0      3.0  251006-08  43.4667        ⋯
#  9614 │  192.28     1.64     6.52      3.0      3.0  251006-08  43.4667
#  9615 │  192.3      1.64     6.52      3.0      3.0  251006-08  43.4667
#                                                   1 column and 9600 rows omitted
#  4764×8 DataFrame
#   Row │ Zeit     Weg      Kraft    Länge    dL_ORG   Name       Stress     Str ⋯
#       │ Float64  Float64  Float64  Float64  Float64  String     Float64    Flo ⋯
# ──────┼─────────────────────────────────────────────────────────────────────────
#     1 │    0.22  0.02904    0.109   0.0018   0.0001  251006-01   0.726667  1.0 ⋯
#     2 │    0.24  0.02941    0.11    0.003    0.0013  251006-01   0.733333  1.3
#     3 │    0.26  0.02967    0.114   0.003    0.0013  251006-01   0.76      1.3
#     4 │    0.28  0.03014    0.116   0.0038   0.0021  251006-01   0.773333  2.1
#     5 │    0.3   0.0305     0.117   0.0038   0.0021  251006-01   0.78      2.1 ⋯
#     6 │    0.32  0.03086    0.118   0.0048   0.0031  251006-01   0.786667  3.1
#     7 │    0.34  0.03123    0.121   0.0048   0.0031  251006-01   0.806667  3.1
#     8 │    0.36  0.03149    0.122   0.0076   0.0059  251006-01   0.813333  5.9
#   ⋮   │    ⋮        ⋮        ⋮        ⋮        ⋮         ⋮          ⋮          ⋱
#  4758 │   98.54  1.66729    6.995   2.9901   2.9884  251006-01  46.6333    0.0 ⋯
#  4759 │   98.56  1.6676     6.995   2.9901   2.9884  251006-01  46.6333    0.0
#  4760 │   98.58  1.66791    6.993   2.9936   2.9919  251006-01  46.62      0.0
#  4761 │   98.6   1.66828    6.991   2.9936   2.9919  251006-01  46.6067    0.0
#  4762 │   98.62  1.66864    6.987   2.9971   2.9954  251006-01  46.58      0.0 ⋯
#  4763 │   98.64  1.66895    6.986   2.9998   2.9981  251006-01  46.5733    0.0
#  4764 │   98.66  1.66921    6.983   2.9998   2.9981  251006-01  46.5533    0.0
#                                                   1 column and 4749 rows omitted
#  1716×8 DataFrame
#   Row │ Zeit     Weg      Kraft    Länge    dL_ORG   Name       Stress     Str ⋯
#       │ Float64  Float64  Float64  Float64  Float64  String     Float64    Flo ⋯
# ──────┼─────────────────────────────────────────────────────────────────────────
#     1 │    0.02     0.04     0.1      0.0      0.0   251006-06   0.666667   0. ⋯
#     2 │    0.04     0.04     0.1      0.0      0.0   251006-06   0.666667   0.
#     3 │    0.06     0.04     0.1      0.0      0.0   251006-06   0.666667   0.
#     4 │    0.08     0.04     0.1      0.0      0.0   251006-06   0.666667   0.
#     5 │    0.1      0.04     0.1      0.0      0.0   251006-06   0.666667   0. ⋯
#     6 │    0.12     0.04     0.11     0.0      0.0   251006-06   0.733333   0.
#     7 │    0.14     0.04     0.11     0.0      0.0   251006-06   0.733333   0.
#     8 │    0.16     0.04     0.12     0.0      0.0   251006-06   0.8        0.
#   ⋮   │    ⋮        ⋮        ⋮        ⋮        ⋮         ⋮          ⋮          ⋱
#  1710 │   34.2      1.74     8.13     2.96     2.96  251006-06  54.2        0. ⋯
#  1711 │   34.22     1.74     8.12     2.97     2.97  251006-06  54.1333     0.
#  1712 │   34.24     1.75     8.12     2.98     2.98  251006-06  54.1333     0.
#  1713 │   34.26     1.75     8.11     2.98     2.98  251006-06  54.0667     0.
#  1714 │   34.28     1.75     8.11     2.99     2.99  251006-06  54.0667     0. ⋯
#  1715 │   34.3      1.75     8.1      3.0      3.0   251006-06  54.0        0.
#  1716 │   34.32     1.75     8.1      3.0      3.0   251006-06  54.0        0.
#                                                   1 column and 1701 rows omitted

# %%
print(df_Group_Total)
# Out:
# Any
# Excessive output truncated after 3201916 bytes.

# %%
df_Group=[]

for i in [8, 12]
    push!(df_Group,df_Group_Total[i])
    
end

Temperaturen=[22, 100]

for i in 1:length(df_Group)

    fig4=plotVariableTemperature!(fig4,ax1_4,ax2_4,df_Group[i],[0.1 0.25],[0 100],Temperaturen[i])

end

axislegend(ax1_4, labelsize=font-10, framevisible=false)
axislegend(ax2_4, labelsize=font-10, framevisible=false)
# Out:
# Legend()

# %%
fig4
