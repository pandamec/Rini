# %%
using Pkg
using CSV
using DataFrames
using Polynomials
using CairoMakie
using Statistics

# %% [markdown]
# ## Plots

# %% [markdown]
# ### fig1

# %%
using Plots

# Plot the first curve with lines and markers
fig = Figure(resolution = (1200, 1200))
font=24
ax1 = Axis(fig[1,1],
    xlabel = L"\epsilon (%)",
    ylabel = L"\sigma (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)


ax2 = Axis(fig[1,2],
    xlabel = L"\epsilon (%)",
    ylabel = L"\sigma (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)


ax3 = Axis(fig[2,1],
    xlabel = L"v (%/min)",
    ylabel = L"E (GPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)

ax4 = Axis(fig[2,2],
    xlabel = L"v (%/min)",
    ylabel = L"\sigma_B (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)

ax5 = Axis(fig[2,3],
    xlabel = L"v (%/min)",
    ylabel = L"\sigma_F (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)
# Out:
# Axis with 0 plots:

# %% [markdown]
# ### Fig2

# %%
fig2 = Figure(resolution = (1200, 1200))
font=24
ax1_2 = Axis(fig2[1,1],
    xlabel = L"\epsilon (%)",
    ylabel = L"\sigma (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)


ax2_2 = Axis(fig2[1,2],
    xlabel = L"\epsilon (%)",
    ylabel = L"\sigma (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)


ax3_2 = Axis(fig2[2,1],
    xlabel = L"v (%/min)",
    ylabel = L"E (GPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)

ax4_2 = Axis(fig2[2,2],
    xlabel = L"v (%/min)",
    ylabel = L"\sigma_B (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)

ax5_2 = Axis(fig2[2,3],
    xlabel = L"v (%/min)",
    ylabel = L"\sigma_F (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)
# Out:
# Axis with 0 plots:

# %% [markdown]
# ### Fig3

# %%
fig3 = Figure(resolution = (1200, 1200))
font=24
ax1_3 = Axis(fig3[1,1],
    xlabel = L"\epsilon (%)",
    ylabel = L"\sigma (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)


ax2_3 = Axis(fig3[1,2],
    xlabel = L"\epsilon (%)",
    ylabel = L"\sigma (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)


ax3_3 = Axis(fig3[2,1],
    xlabel = L"v (%/min)",
    ylabel = L"E (GPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)

ax4_3 = Axis(fig3[2,2],
    xlabel = L"v (%/min)",
    ylabel = L"\sigma_B (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)

ax5_3 = Axis(fig3[2,3],
    xlabel = L"v (%/min)",
    ylabel = L"\sigma_F (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)
# Out:
# Axis with 0 plots:

# %% [markdown]
# ### Fig4

# %%
fig4 = Figure(resolution = (1200, 600))
font=24
ax1_4 = Axis(fig4[1,1],
    xlabel = L"\epsilon (%)",
    ylabel = L"\sigma (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)


ax2_4 = Axis(fig4[1,2],
    xlabel = L"\epsilon (%)",
    ylabel = L"\sigma (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)
# Out:
# Axis with 0 plots:

# %% [markdown]
# ## Functions

# %%
function import_TIRA(file_path)
    
    df=CSV.read(file_path,DataFrame) 
    df.Zeit = parse.(Float64, replace.(df.Zeit, "," => "."))
    df.Länge = parse.(Float64, replace.(df.Länge, "," => "."))
    df.Weg = parse.(Float64, replace.(df.Weg, "," => "."))
    #df.Dehnung = parse.(Float64, replace.(df.Dehnung, "," => "."))
    df.Kraft = parse.(Float64, replace.(df.Kraft, "," => "."))
    df.dL_ORG = parse.(Float64, replace.(df.dL_ORG, "," => "."))

    return df

end

function filter_range(df::DataFrame, column::String, low, high)
    return filter(row -> low ≤ row[column] ≤ high, df)
end
# Out:
# filter_range (generic function with 1 method)

# %%
function get_corresponding(df::DataFrame, search_col::Symbol, search_val, return_col::Symbol)
    row = findfirst(df[!, search_col] .== search_val)
    return row === nothing ? missing : df[row, return_col]
end
# Out:
# get_corresponding (generic function with 1 method)

# %%
function Elinear(X,Y)
    p_fit=fit(X,Y,1)
    y_fit = p_fit.(X)
    residuals = y_fit - Y   # residuals
    
    σ_res = std(residuals, corrected=true) 
    X_mean = mean(X)
    stderr_slope = σ_res / sqrt(sum((X .- X_mean).^2))
    df_fit=DataFrame([X,y_fit],[:Strain,:Stress])

    return df_fit,stderr_slope
end
# Out:
# Elinear (generic function with 1 method)

# %%
function u_E(X,Y)
    p_fit=fit(X,Y,1)
    y_fit = p_fit.(X)
    residuals = y_fit .- Y   # residuals
    n = length(X)
    σ = sqrt(sum(residuals.^2) / (n - 2))
    
    #σ_res = std(residuals, corrected=true) 
    X̄ = mean(X)
    σ_err = σ / sqrt(sum((X .- X̄).^2))
    
    #X_mean = mean(X)
    #stderr_slope = σ_res / sqrt(sum((X .- X_mean).^2))


    return σ_err
end
# Out:
# u_E (generic function with 1 method)

# %%
function getMechanicalProperties(fig,ax1,ax2,log_total,df_Group,LinearRange,StressRange,Temperature)

        log=[]
        for i in df_Group
            
            T=i[!,:Zeit]
            X=i[!,:dL_ORG] #%
            Y=i[!,:Stress] #MPa
            df_linear=filter_range(i,"Stress",StressRange[1],StressRange[2])
            df_linear=filter_range(df_linear,"dL_ORG",LinearRange[1],LinearRange[2])
           
            T_linear=df_linear[!,:Zeit]
            X_linear=df_linear[!,:dL_ORG]
            Y_linear=df_linear[!,:Stress]

            sigma0_25=maximum(Y_linear)
            sigmaB=maximum(Y)
            sigmaF=maximum(Y_linear)
            # Fit a 1st-degree polynomial (linear)
            fit_X_T=fit(T_linear,X_linear*60,1)
            
            strainRate=fit_X_T[1]
            
            # Fit a 1st-degree polynomial (linear)
            p_fit=fit(X_linear/100,Y_linear,1)
            y_fit=p_fit.(X_linear/100)
            E_modul=p_fit[1]/1000
            u_EModul=u_E(X_linear/100,Y_linear/1000)


            Makie.scatter!(ax1,X,Y; markersize=12, label = "$(round(strainRate, digits=3)) [%/min]") 
            #Makie.scatter!(ax1,X,Y; markersize=12,)
            Makie.scatter!(ax2,X_linear,Y_linear; markersize=12, label = "$(round(strainRate, digits=3)) [%/min]")
            Makie.lines!(ax2,X_linear,y_fit; linewidth=2, label = " Fit$(round(strainRate, digits=3)) [%/min]")
            
            δ_B=get_corresponding(i,:Stress,maximum(i[!,:Stress]),:dL_ORG)
            sum=Dict("Probe"=>i[1,:Name],
                    " Strain Rate[%/min]"=>strainRate,
                    "E[GPa] "=>E_modul,
                    "u_E[GPa] "=>u_EModul,
                    "sigma0_25% "=> sigma0_25,
                    "sigmaMax"=> sigmaB,
                    "δ_B"=> δ_B,
                    "δ_F/δ_B"=>df_linear[end,:dL_ORG]*100/δ_B,
                    "Temperature [C]"=> Temperature,
                    "LinearRange [%]"=>[df_linear[1,:dL_ORG],df_linear[end,:dL_ORG]])
            push!(log,sum)
            push!(log_total,sum)
            


        end

        axislegend(ax1, labelsize=font-10, framevisible=false)
        axislegend(ax2, labelsize=font-10, framevisible=false)

        df_log=DataFrame(log)
        return df_log,log_total,fig

end
# Out:
# getMechanicalProperties (generic function with 1 method)

# %%
function plotVariableTemperature!(fig,ax1,ax2,df,LinearRange,StressRange,Temperature)

        log=[]
        
            
            T=df[!,:Zeit]
            X=df[!,:dL_ORG]
            Y=df[!,:Stress]
            df_linear=filter_range(df,"Stress",StressRange[1],StressRange[2])
            df_linear=filter_range(df_linear,"dL_ORG",LinearRange[1],LinearRange[2])
            T_linear=df_linear[!,:Zeit]
            X_linear=df_linear[!,:dL_ORG]
            Y_linear=df_linear[!,:Stress]

            # Fit a 1st-degree polynomial (linear)
            fit_X_T=fit(T_linear,X_linear*60,1)
            
            strainRate=fit_X_T[1]


            Makie.scatter!(ax1,X,Y; markersize=12, label = "T=$Temperature C v=$(round(strainRate, digits=3)) [%/min]")
            
            Makie.scatter!(ax2,X_linear,Y_linear; markersize=12, label = "T=$Temperature C v=$(round(strainRate, digits=3)) [%/min]")
            
           
   
        return fig

end
# Out:
# plotVariableTemperature! (generic function with 1 method)

# %%
function plotProperties!(fig, df_log,ax1,ax2,ax3)
        

        epsilon=df_log[!," Strain Rate[%/min]"]
        E=df_log[!,"E[GPa] "]
        Makie.scatter!(ax1,epsilon,E)
        Makie.lines!(ax1,epsilon,E)

        Makie.scatter!(ax2,df_log[!," Strain Rate[%/min]"],df_log[!,"sigmaMax"])
        Makie.lines!(ax2,df_log[!," Strain Rate[%/min]"],df_log[!,"sigmaMax"])


        Makie.scatter!(ax3,df_log[!," Strain Rate[%/min]"],df_log[!,"sigma0_25% "])
        Makie.lines!(ax3,df_log[!," Strain Rate[%/min]"],df_log[!,"sigma0_25% "])
        
        
        return fig

end
# Out:
# plotProperties! (generic function with 1 method)

# %% [markdown]
# ## Proben Geometrie

# %%
## Geometrie
w=10*1e-3 # Width
t=15*1e-6 # thickness
l=75*1e-3 # length
As=w*t    # stress section
# Out:
# 1.5e-7

# %% [markdown]
# ## Raum Temperatur

# %%
log_total=[]
# Out:
# Any[]

# %%
#### Raum T

    BaseName="AP5ZK04/251103-"
    name="251103-"
    df_Group=[]
    df_Group_Total=[]
    for i in [1,2]
        file_path = "$(BaseName)$(i).csv"
        df=import_TIRA(file_path)
        df[!,:Name]=fill("$(name)$(i)", nrow(df))
        df[!,:Stress]=df[!,:Kraft]*1e-6/As
        df[!,:Strain]=df[!,:dL_ORG]/100
        df_filtered=filter_range(df,"dL_ORG",0,3)
        push!(df_Group,df_filtered)
        push!(df_Group_Total,df_filtered)
    end

    df_log,log_total,fig=getMechanicalProperties(fig,ax1,ax2,log_total,df_Group,[0.1 1.2],[0 100],22)
    fig=plotProperties!(fig, df_log,ax3,ax4,ax5)
    fig

# %%
df_log
# Out:
# 2×10 DataFrame
#  Row │ δ_F/δ_B  LinearRange [%]  u_E[GPa]   Probe     δ_B      Temperature [C] ⋯
#      │ Float64  Vector{Float64}  Float64    String    Float64  Int64           ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 50.2092  [0.11, 1.2]      0.0147932  251103-1     2.39               22 ⋯
#    2 │ 47.4308  [0.1, 1.2]       0.015328   251103-2     2.53               22
#                                                                4 columns omitted

# %% [markdown]
# ## Temperatur 50C

# %%
#### Gesamtgruppe um 50 °C

    BaseName="AP5ZK04/251103-"
    name="251103-0"
    df_Group=[]

   for i in [3,4,5,6,7]
        file_path = "$(BaseName)$(i).csv"
        df=import_TIRA(file_path)
        df[!,:Name]=fill("$(name)$(i)", nrow(df))
        df[!,:Stress]=df[!,:Kraft]*1e-6/As
        df[!,:Strain]=df[!,:dL_ORG]/100
        df_filtered=filter_range(df,"dL_ORG",0.1,3)
        push!(df_Group,df_filtered)
        push!(df_Group_Total,df_filtered)
    end

    df_log,log_total,fig2=getMechanicalProperties(fig2,ax1_2,ax2_2,log_total,df_Group,[0.1 1],[0 100],50)
    fig2=plotProperties!(fig2, df_log,ax3_2,ax4_2,ax5_2)

    fig2

# %% [markdown]
# ## Temperatur 100C

# %%
#### Gesamtgruppe um 100 °C

    BaseName="AP5ZK04/251103-"
    name="251103-"
    df_Group=[]

   for i in [8,9,10]
        file_path = "$(BaseName)$(i).csv"
        df=import_TIRA(file_path)
        df[!,:Name]=fill("$(name)$(i)", nrow(df))
        df[!,:Stress]=df[!,:Kraft]*1e-6/As
        s0=df[1,:dL_ORG]
        df[!,:dL_ORG]=(df[!,:dL_ORG].-s0)
        df[!,:Strain]=df[!,:dL_ORG]/100
        df_filtered=filter_range(df,"dL_ORG",0.1,3)
        push!(df_Group,df_filtered)
        push!(df_Group_Total,df_filtered)
    end


    df_log,log_total,fig3=getMechanicalProperties(fig3,ax1_3,ax2_3,log_total,df_Group,[0.8 1.5],[0 100],100)
    fig3=plotProperties!(fig3, df_log,ax3_3,ax4_3,ax5_3)

    fig3

# %% [markdown]
# ## Comparison

# %%
df_Group_Total[1]
# Out:
# 319×8 DataFrame
#  Row │ Zeit     Weg      Kraft    Länge    dL_ORG   Name      Stress     Strai ⋯
#      │ Float64  Float64  Float64  Float64  Float64  String    Float64    Float ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │    0.02     0.05     0.1      0.0      0.0   251103-1   0.666667   0.0  ⋯
#    2 │    0.04     0.05     0.1      0.0      0.0   251103-1   0.666667   0.0
#    3 │    0.06     0.05     0.09     0.0      0.0   251103-1   0.6        0.0
#    4 │    0.08     0.05     0.09     0.0      0.0   251103-1   0.6        0.0
#    5 │    0.1      0.05     0.09     0.0      0.0   251103-1   0.6        0.0  ⋯
#    6 │    0.12     0.05     0.09     0.0      0.0   251103-1   0.6        0.0
#    7 │    0.14     0.05     0.1      0.0      0.0   251103-1   0.666667   0.0
#    8 │    0.16     0.05     0.1      0.0      0.0   251103-1   0.666667   0.0
#   ⋮  │    ⋮        ⋮        ⋮        ⋮        ⋮        ⋮          ⋮         ⋮  ⋱
# ...

# %%
df_Group=[]
for i in [7,10, 12]
    push!(df_Group,df_Group_Total[i])
    
end

Temperaturen=[22 50 100]

for i in 1:length(df_Group)

    fig4=plotVariableTemperature!(fig4,ax1_4,ax2_4,df_Group[i],[0.1 0.25],[0 100],Temperaturen[i])

end

axislegend(ax1_4, labelsize=font-10, framevisible=false)
axislegend(ax2_4, labelsize=font-10, framevisible=false)
# Out:
# BoundsError: attempt to access 10-element Vector{Any} at index [12]
#
#
#
# Stacktrace:
#
#  [1] getindex(A::Vector{Any}, i1::Int64)
#
#    @ Base .\essentials.jl:13
#
#  [2] top-level scope
#
#    @ d:\01 Projekt\03 Programm\Rini aktuell\Rini\development\04 zugversuch\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X42sZmlsZQ==.jl:3

# %%
fig4

# %% [markdown]
# ## Ergebnisse

# %%
df_log_total=DataFrame(log_total)
df_log_total
# Out:
# 10×10 DataFrame
#  Row │ δ_F/δ_B  LinearRange [%]  u_E[GPa]   Probe      δ_B      Temperature [C ⋯
#      │ Float64  Vector{Float64}  Float64    String     Float64  Int64          ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 50.2092  [0.11, 1.2]      0.0147932  251103-1      2.39               2 ⋯
#    2 │ 47.4308  [0.1, 1.2]       0.015328   251103-2      2.53               2
#    3 │ 38.5827  [0.1, 0.98]      0.0212984  251103-03     2.54               5
#    4 │ 38.61    [0.1, 1.0]       0.0365084  251103-04     2.59               5
#    5 │ 45.4545  [0.1, 1.0]       0.0160777  251103-05     2.2                5 ⋯
#    6 │ 45.2489  [0.11, 1.0]      0.0133979  251103-06     2.21               5
#    7 │ 43.29    [0.1, 1.0]       0.0143205  251103-07     2.31               5
#    8 │ 60.241   [0.8, 1.5]       0.0159626  251103-8      2.49              10
# ...

# %%
fig

# %%
fig2

# %%
fig3

# %% [markdown]
# ## Bericht Plots

# %%
fig = Figure(resolution = (1000, 600))
font=36
ax1 = Axis(fig[1,1],
    xlabel = L"\epsilon (%)",
    ylabel = L"\sigma (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)
# Out:
# Axis with 0 plots:

# %%
print(df_Group)
# Out:
# Any[527×8 DataFrame
#  Row │ Zeit     Weg      Kraft    Länge    dL_ORG   Name       Stress    Strain
#      │ Float64  Float64  Float64  Float64  Float64  String     Float64   Float64
# ─────┼───────────────────────────────────────────────────────────────────────────
#    1 │    0.54     0.18     0.58     0.11     0.1   251103-07   3.86667   0.001
#    2 │    0.56     0.19     0.6      0.11     0.1   251103-07   4.0       0.001
#    3 │    0.58     0.19     0.64     0.12     0.11  251103-07   4.26667   0.0011
#    4 │    0.6      0.2      0.65     0.13     0.13  251103-07   4.33333   0.0013
#    5 │    0.62     0.2      0.69     0.13     0.13  251103-07   4.6       0.0013
#    6 │    0.64     0.21     0.74     0.14     0.14  251103-07   4.93333   0.0014
#    7 │    0.66     0.22     0.75     0.15     0.15  251103-07   5.0       0.0015
#    8 │    0.68     0.22     0.78     0.15     0.15  251103-07   5.2       0.0015
# ...

# %%
#### Raum T

    BaseName="AP5ZK03/251103-"
    name="251103-"
    df_Group2=[]
    
    for i in [2,]
        file_path = "$(BaseName)$(i).csv"
        df=import_TIRA(file_path)
        df[!,:Name]=fill("$(name)$(i)", nrow(df))
        df[!,:Stress]=df[!,:Kraft]*1e-6/As
        df[!,:Strain]=df[!,:dL_ORG]/100
        df_filtered=filter_range(df,"dL_ORG",0,3.6)
        push!(df_Group2,df_filtered)
        
    end

    df_log,log_total,fig=getMechanicalProperties(fig,ax1,ax2,log_total,df_Group2,[0.1 0.25],[0 20],22)
    fig=plotProperties!(fig, df_log,ax3,ax4,ax5)
    
   fig
# Out:
# ArgumentError: "AP5ZK03/251103-2.csv" is not a valid file or doesn't exist
#
#
#
# Stacktrace:
#
# ...

# %%
 ax1.xticks = LinearTicks(10)   # 20 divisions on X
 ax1.yticks = LinearTicks(10)
 fig
 save("tensile.svg",fig)
# Out:
# CairoMakie.Screen{SVG}

# %%
fig4 = Figure(resolution = (1200, 600))
font=24
ax1_4 = Axis(fig4[1,1],
    xlabel = L"\epsilon (%)",
    ylabel = L"\sigma (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)


ax2_4 = Axis(fig4[1,2],
    xlabel = L"\epsilon (%)",
    ylabel = L"\sigma (MPa)",
    xlabelsize = font,
    ylabelsize = font,
    xticklabelsize = font - 2,
    yticklabelsize = font - 2,
    xgridstyle = :dash,        # dashed grid
    ygridstyle = :dash,
    xgridvisible = false,
    ygridvisible = false
)
# Out:
# Axis with 0 plots:

# %%
df_Group2
# Out:
# Any[]

# %%
print(df_Group_Total)
# Out:
# Any[319×8 DataFrame
#  Row │ Zeit     Weg      Kraft    Länge    dL_ORG   Name      Stress     Strain
#      │ Float64  Float64  Float64  Float64  Float64  String    Float64    Float64
# ─────┼───────────────────────────────────────────────────────────────────────────
#    1 │    0.02     0.05     0.1      0.0      0.0   251103-1   0.666667   0.0
#    2 │    0.04     0.05     0.1      0.0      0.0   251103-1   0.666667   0.0
#    3 │    0.06     0.05     0.09     0.0      0.0   251103-1   0.6        0.0
#    4 │    0.08     0.05     0.09     0.0      0.0   251103-1   0.6        0.0
#    5 │    0.1      0.05     0.09     0.0      0.0   251103-1   0.6        0.0
#    6 │    0.12     0.05     0.09     0.0      0.0   251103-1   0.6        0.0
#    7 │    0.14     0.05     0.1      0.0      0.0   251103-1   0.666667   0.0
#    8 │    0.16     0.05     0.1      0.0      0.0   251103-1   0.666667   0.0
#    9 │    0.18     0.05     0.1      0.0      0.0   251103-1   0.666667   0.0
# ...

# %%
df_Group=[]

for i in [8, 12]
    push!(df_Group,df_Group_Total[i])
    
end

Temperaturen=[22, 100]

for i in 1:length(df_Group)

    fig4=plotVariableTemperature!(fig4,ax1_4,ax2_4,df_Group[i],[0.1 0.25],[0 100],Temperaturen[i])

end

axislegend(ax1_4, labelsize=font-10, framevisible=false)
axislegend(ax2_4, labelsize=font-10, framevisible=false)
# Out:
# BoundsError: attempt to access 10-element Vector{Any} at index [12]
#
#
#
# Stacktrace:
#
#  [1] getindex(A::Vector{Any}, i1::Int64)
#
#    @ Base .\essentials.jl:13
#
#  [2] top-level scope
#
#    @ d:\01 Projekt\03 Programm\Rini aktuell\Rini\development\04 zugversuch\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X64sZmlsZQ==.jl:4

# %%
fig4
